# %% [markdown]
# ## Import necessary libraries for data cleaning

# %%
# %pip install pandas numpy
# Out:
# Collecting pandas
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy
#   Using cached numpy-2.2.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\onedrive - universiti malaya\desktop\datavizhub\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\user\onedrive - universiti malaya\desktop\datavizhub\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached numpy-2.2.3-cp312-cp312-win_amd64.whl (12.6 MB)
# Using cached pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Using cached tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.2.3 pandas-2.2.3 pytz-2025.1 tzdata-2025.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load dataset and preliminary cleaning

# %%
df = pd.read_csv('CityExpensesAndRevenue.csv')
print(df.columns)
rows, columns = df.shape
print(f"Number of rows before cleaning: {rows}")
print(f"Number of columns before cleaning: {columns}")

# Rename columns
df = df.rename(columns={
    '_id': 'id',
    'fund_number': 'fund_id',
    'department_number': 'department_id',
    'ledger_descrpition': 'ledger_description',
    'cost_center_number': 'cost_center_id'
})

# Drop unnecessary columns
df = df.drop(columns=['object_account_number', 'object_account_description'])

# Remove rows that has ledger_description = 'Transfers' or have duplicate foreign key values
df = df[df['ledger_description'] != 'Transfers']
df = df[df['fund_id'] != 78770]
df = df[df['fund_id'] != 40015]
df = df[df['department_id'] != 999]

rows, columns = df.shape
print(f"Number of rows after dropping: {rows}")
print(f"Number of columns after dropping: {columns}")
df.head()
# Out:
# Index(['_id', 'fund_number', 'fund_description', 'department_number',
#        'department_name', 'cost_center_number', 'cost_center_description',
#        'object_account_number', 'object_account_description',
#        'general_ledger_date', 'amount', 'ledger_code', 'ledger_descrpition'],
#       dtype='object')
# Number of rows before cleaning: 617753
# Number of columns before cleaning: 13
# Number of rows after dropping: 609499
# Number of columns after dropping: 11
#          id  fund_id fund_description  department_id  \
# 0  77837069    11101     GENERAL FUND            103
# 1  77837070    11101     GENERAL FUND            107
# 2  77837071    11101     GENERAL FUND            107
# 3  77837072    11101     GENERAL FUND            230
# 4  77837073    11101     GENERAL FUND            250
#
#             department_name  cost_center_id   cost_center_description  \
# 0  Innovation & Performance          103000  INNOVATION & PERFORMANCE
# 1     Department of Finance          107000                   FINANCE
# 2     Department of Finance          107000                   FINANCE
# 3                DPS-Police          230000        PS - POLICE BUREAU
# 4                  DPS-Fire          250000          PS - FIRE BUREAU
#
#   general_ledger_date   amount  ledger_code ledger_description
# 0          31/12/2020  1543.98            5           Expenses
# 1          31/12/2020  4453.96            5           Expenses
# 2          31/12/2020   197.56            5           Expenses
# 3          31/12/2020  2243.43            5           Expenses
# 4          31/12/2020  9655.92            5           Expenses

# %%
# Check for null values
null_values = df.isnull().sum()
print("\nNull values in each column:")
print(null_values)

# Check if there are any duplicate values in the 'id' column
duplicates = df['id'].duplicated().sum()

# Print the number of duplicate values (if any)
print(f"Number of duplicate values in 'id' column: {duplicates}")
# Out:
# Null values in each column:
# id                         0
# fund_id                    0
# fund_description           0
# department_id              0
# department_name            0
# cost_center_id             0
# cost_center_description    0
# general_ledger_date        0
# amount                     0
# ledger_code                0
# ledger_description         0
# dtype: int64
# Number of duplicate values in 'id' column: 0

# %%
# Get unique values for each column
for column in df.columns:
    unique_values = df[column].unique()
    print(f"\nUnique values in column '{column}':")
    print(unique_values)
# Out:
# Unique values in column 'id':
# [77837069 77837070 77837071 ... 78454581 78454582 78454583]
#
# Unique values in column 'fund_id':
# [11101 28050 28020 29040 24067 28033 28003 26030 28055 28004 23000 78765
#  26010 24037 78768 32000 24016 26020 28070 28043 28053 40120 29060 75020
#  78160 78170 40017 40018 40119 40019 40118 24063 28085 40001 28045 22000
#  40116 40020 40114 78540 40012 78590 40117 78595 78740 78728 24041 40014
#  24084 78750 24069 40115 24019 24009 24046 28040 28080 40011 24049 24042
#  24800 28015 29080 29065 78400 29070 26050 40013 24040 24081 26060 28067
#  28064 24025 26080 78137 24060 29075 28065 24006 26040 78138 28037 24030
#  24062 78769 78535 78570 24045 24043 24070 28063 78575 29050 78135 29074
#  26090 28060 12881 78722]
#
# Unique values in column 'fund_description':
# ['GENERAL FUND' 'SENIOR CITIZENS PROG TF' 'EEOC TRUST FUND' 'GRANTS FUND'
#  'POLICE SECONDARY EMPL T.F.' 'MELLON PARK TENNIS TF' 'ARAD-PUBLIC WORKS'
#  'HUD-FAIR HOUSING PROG TF' 'SPEC SUM FOOD SERVICE TF' 'ARAD-PARKS' 'JTPA'
#  'TREE TAXING BODIES' 'CDBG FUND' 'EMS REIMB EVENTS TRUST FUND'
#  '3 TAXING BODIES ESCROW TF' 'DEBT SERVICE- PROJ FUND'
#  'CONFISCATED NARC PROCEEDS' 'EMERGENCY SHELTERS PROG TF' 'SOLID WASTE TF'
#  'PUBLIC WORKS TRUST FUND' 'SHADE TREE TRUST FUND' '2020 PAYGO'
#  'SPECIAL PKS PROG/GREAT RACE' "WORKERS' COMP COMMUTATIONS"
#  'VEBA- HEALTH INSURANCE' "VEBA-WORKERS' COMP" 'PROJECT FUND 2017 BOND'
#  'PROJECT FUND 2018 BOND' '2019 PAYGO' 'PROJECT FUND 2019 BOND'
#  '2018 PAYGO' 'PEMA AND HOMELAND SECURITY' 'GREEN INITIATIVE TRUST FUND'
#  'CAP PROJ - PROJ FUND' 'SCHENLEY PARK RINK TF' 'LIQUID FUELS TAX'
#  '2016 PAYGO' 'PROJECT FUND 2020 BOND' 'TIP PROJECTS' 'FIRE ESCROW'
#  'Project Fund-2012 Bond' 'REAL ESTATE TAX REFUNDS - CITY' '2017 PAYGO'
#  'REAL ESTATE TAX REFUNDS-SCHOOL' 'EMPL TRAVEL EXPENSE ADVANCE TF'
#  'DEMOLITION TF' 'HAZARD MAERIALS TRUST FUND' '2014 PAYGO'
#  'CROSSING GUARD SPECIAL EVENTS' 'PITTSBURGH CODE TF'
#  'PUBLIC SAFETY TRAINING TF' '2015 PAYGO' 'CONFISCATED NON-NARC PROCEEDS'
#  'CODE TRUST FUND' 'MICROFILM PERMIT PLANS TF' 'PGH COMM ON HUMAN TELA TF'
#  'VERIZON FRANCHISE TF' 'CAPITAL PROJECTS - 2006 BOND' 'Mounted Police TF'
#  'GRAFFITI TRUST FUND' 'SOUTH SIDE PARKING ENHANCEMENT'
#  'COMCAST FRANCHISE TF' 'FRICK PARK TRUST FUND'
#  'PUBLIC SAFETY SUPPORT TRUST FU' 'ESCHEAT FUND'
#  'DISTRICT 9 CRIME PREVENTION' 'HOPWA' '2013 PAYGO'
#  'FEDERAL TASK FORCE TF' "YCPC/MAYOR'S YOUTH INIT TF" 'ARC'
#  'WORKFORCE DEVELOPMENT FUND' 'STORMWATER MANAGEMENT TRUST FU'
#  'DURG ABUSE RESISTANCE ED TF' 'Brownfield Economic Developmen'
#  'OPEB TRUST-POLICE' 'OPERATION WEED & SEED FUND' 'Facilities Trust Fund'
#  'WAYFINDERS SIGNAGE TF' 'CRIMINAL INTELLIGENCE'
#  'STATE EMERGENCY SHELTER PROG' 'OPEB TRUST-FIRE' 'PHIPPS CONSERVATORY'
#  'AUTO THEFT TF II' 'PANGIS TRUST FUND' 'VENDING TF-CONTROLLER'
#  'ETHICS BOARD TRUST FUND' 'EARNED INCOME TAX REFUNDS-CITY'
#  'LOCAL LAW ENFORCEMENT' 'HIGHWAY SAFETY TF' 'RENTAL PERMIT TF'
#  'OPEN SPACE TRUST FUND' 'EARNED INC TAX REFUNDS-SCHOOL' 'STIMULUS FUND'
#  'OPEB TRUST FUND' 'LIBERTY AVE BIKE LANE GRANT' 'HPRP'
#  'SWIMMING POOL MAINT TF' 'COPIER MANAGEMENT & POSTAGE TF'
#  "CONTROLLER'S FIN MAGMT. I.S."]
#
# Unique values in column 'department_id':
# [103 107 230 250 420 500 101 112 102 105 106 108 109 110 130 210 240 280
#  410 430 450 600 400 122 220 820 840 183 121 440 270]
#
# Unique values in column 'department_name':
# ['Innovation & Performance' 'Department of Finance' 'DPS-Police'
#  'DPS-Fire' 'DPW-Operations' 'Parks and Recreation' 'City Council'
#  'City Clerk' "Mayor's Office" 'Human Relations Commission'
#  "Controller's Office" 'Department of Law' 'Personnel/Civil Service'
#  'Department of City Planning' 'Permits Licenses and Inspectio'
#  'DPS-Administration' 'OMI' 'DPS-Animal Care and Control'
#  'DPW-Administration' 'DPW- Environmental Services' 'DPW - Facilities'
#  'Mobility and Infrastructure' 'Public Works'
#  'Office of  Management and Budg' 'DPS-Emergency Medical Services'
#  'URA Projects' 'Equipment Leasing Authority'
#  'Equal Opportunity Review Commi' 'Finance, Procurement, Fleet, a'
#  'DPW-Transportation and Engine' 'DPS-Building Inspection']
#
# Unique values in column 'cost_center_id':
# [    103000     107000     230000 ... 4029400023 8425589910 2329400043]
#
# Unique values in column 'cost_center_description':
# ['INNOVATION & PERFORMANCE' 'FINANCE' 'PS - POLICE BUREAU' ...
#  'EAST LIBERTY TRID PLANNING' 'DCED-CITY BUSINESS DISTRICT IM'
#  'USDOT/MOTOR SAFETY 2']
#
# Unique values in column 'general_ledger_date':
# ['31/12/2020' '30/12/2020' '29/12/2020' ... '5/1/2012' '4/1/2012'
#  '3/1/2012']
#
# Unique values in column 'amount':
# [ 1.5439800e+03  4.4539600e+03  1.9756000e+02 ...  1.6920380e+04
#   1.0938280e+05 -2.7009139e+05]
#
# Unique values in column 'ledger_code':
# [5 4 8]
#
# Unique values in column 'ledger_description':
# ['Expenses' 'Revenues']

# %% [markdown]
# ## Renaming of data for consistency

# %%
replace_dict_fund_description = {
    'GENERAL FUND': 'General Fund',
    'SENIOR CITIZENS PROG TF': 'Senior Citizens Program Trust Fund',
    'EEOC TRUST FUND': 'Equal Employment Opportunity Commission Trust Fund',
    'GRANTS FUND': 'Grants Fund',
    'POLICE SECONDARY EMPL T.F.': 'Police Secondary Employment Trust Fund',
    'MELLON PARK TENNIS TF': 'Mellon Park Tennis Trust Fund',
    'ARAD-PUBLIC WORKS': 'Allegheny Regional Asset District Public Works',
    'HUD-FAIR HOUSING PROG TF': 'Housing and Urban Development Fair Housing Program Trust Fund',
    'SPEC SUM FOOD SERVICE TF': 'Special Summer Food Service Trust Fund',
    'ARAD-PARKS': 'Allegheny Regional Asset District Parks',
    'JTPA': 'Job Training Partnership Act',
    'TREE TAXING BODIES': 'Tree Taxing Bodies',
    'CDBG FUND': 'Community Development Block Grant Fund',
    'EMS REIMB EVENTS TRUST FUND': 'Emergency Medical Services Reimbursement Events Trust Fund',
    '3 TAXING BODIES ESCROW TF': 'Three Taxing Bodies Escrow Trust Fund',
    'DEBT SERVICE- PROJ FUND': 'Debt Service Project Fund',
    'WORKERS\' COMP FUND': 'Workers Compensation Fund',
    'CONFISCATED NARC PROCEEDS': 'Confiscated Narcotics Proceeds',
    'EMERGENCY SHELTERS PROG TF': 'Emergency Shelters Program Trust Fund',
    'SOLID WASTE TF': 'Solid Waste Trust Fund',
    'PUBLIC WORKS TRUST FUND': 'Public Works Trust Fund',
    'SHADE TREE TRUST FUND': 'Shade Tree Trust Fund',
    '2020 PAYGO': '2020 Pay-As-You-Go',
    'SPECIAL PKS PROG/GREAT RACE': 'Special Parks Program Great Race',
    'WORKERS\' COMP COMMUTATIONS': 'Workers Compensation Commutations',
    'VEBA- HEALTH INSURANCE': 'Voluntary Employees Beneficiary Association Health Insurance',
    'VEBA-WORKERS\' COMP': 'Voluntary Employees Beneficiary Association Workers Compensation',
    'PROJECT FUND 2017 BOND': 'Project Fund 2017 Bond',
    'PROJECT FUND 2018 BOND': 'Project Fund 2018 Bond',
    '2019 PAYGO': '2019 Pay-As-You-Go',
    'PROJECT FUND 2019 BOND': 'Project Fund 2019 Bond',
    '2018 PAYGO': '2018 Pay-As-You-Go',
    'PEMA AND HOMELAND SECURITY': 'Pennsylvania Emergency Management Agency and Homeland Security',
    'GREEN INITIATIVE TRUST FUND': 'Green Initiative Trust Fund',
    'CAP PROJ - PROJ FUND': 'Capital Project Fund',
    'SCHENLEY PARK RINK TF': 'Schenley Park Rink Trust Fund',
    'LIQUID FUELS TAX': 'Liquid Fuels Tax',
    '2016 PAYGO': '2016 Pay-As-You-Go',
    'PROJECT FUND 2020 BOND': 'Project Fund 2020 Bond',
    'TIP PROJECTS': 'Transportation Improvement Program Projects',
    'FIRE ESCROW': 'Fire Escrow',
    'PROJECT FUND 2015 BOND': 'Project Fund 2015 Bond',
    'Project Fund-2012 Bond': 'Project Fund 2012 Bond',
    'REAL ESTATE TAX REFUNDS - CITY': 'Real Estate Tax Refunds City',
    '2017 PAYGO': '2017 Pay-As-You-Go',
    'REAL ESTATE TAX REFUNDS-SCHOOL': 'Real Estate Tax Refunds School',
    'EMPL TRAVEL EXPENSE ADVANCE TF': 'Employee Travel Expense Advance Trust Fund',
    'DEMOLITION TF': 'Demolition Trust Fund',
    'HAZARD MAERIALS TRUST FUND': 'Hazardous Materials Trust Fund',
    '2014 PAYGO': '2014 Pay-As-You-Go',
    'CROSSING GUARD SPECIAL EVENTS': 'Crossing Guard Special Events',
    'PITTSBURGH CODE TF': 'Pittsburgh Code Trust Fund',
    'PUBLIC SAFETY TRAINING TF': 'Public Safety Training Trust Fund',
    '2015 PAYGO': '2015 Pay-As-You-Go',
    'CONFISCATED NON-NARC PROCEEDS': 'Confiscated Non-Narcotics Proceeds',
    'CODE TRUST FUND': 'Code Trust Fund',
    'MICROFILM PERMIT PLANS TF': 'Microfilm Permit Plans Trust Fund',
    'PGH COMM ON HUMAN TELA TF': 'Pittsburgh Commission on Human Relations Trust Fund',
    'VERIZON FRANCHISE TF': 'Verizon Franchise Trust Fund',
    'CAPITAL PROJECTS - 2006 BOND': 'Capital Projects 2006 Bond',
    'Mounted Police TF': 'Mounted Police Trust Fund',
    'GRAFFITI TRUST FUND': 'Graffiti Trust Fund',
    'SOUTH SIDE PARKING ENHANCEMENT': 'South Side Parking Enhancement',
    'COMCAST FRANCHISE TF': 'Comcast Franchise Trust Fund',
    'FRICK PARK TRUST FUND': 'Frick Park Trust Fund',
    'PUBLIC SAFETY SUPPORT TRUST FU': 'Public Safety Support Trust Fund',
    'ESCHEAT FUND': 'Escheat Fund',
    'DISTRICT 9 CRIME PREVENTION': 'District 9 Crime Prevention',
    'HOPWA': 'Housing Opportunities for Persons With AIDS',
    '2013 PAYGO': '2013 Pay-As-You-Go',
    'FEDERAL TASK FORCE TF': 'Federal Task Force Trust Fund',
    'YCPC/MAYOR\'S YOUTH INIT TF': 'York County Planning Commission Mayor\'s Youth Initiative Trust Fund',
    'ARC': 'Appalachian Regional Commission',
    'WORKFORCE DEVELOPMENT FUND': 'Workforce Development Fund',
    'STORMWATER MANAGEMENT TRUST FU': 'Stormwater Management Trust Fund',
    'DURG ABUSE RESISTANCE ED TF': 'Drug Abuse Resistance Education Trust Fund',
    'Brownfield Economic Developmen': 'Brownfield Economic Development Fund',
    'OPEB TRUST-POLICE': 'Other Post-Employment Benefits Trust Fund Police',
    'ARCHIVES AND RECORDS MANAGEMEN': 'Archives and Records Management',
    'OPERATION WEED & SEED FUND': 'Operation Weed and Seed Fund',
    'Facilities Trust Fund': 'Facilities Trust Fund',
    'WAYFINDERS SIGNAGE TF': 'Wayfinders Signage Trust Fund',
    'CRIMINAL INTELLIGENCE': 'Criminal Intelligence Fund',
    'STATE EMERGENCY SHELTER PROG': 'State Emergency Shelter Program',
    'OPEB TRUST-FIRE': 'Other Post-Employment Benefits Trust Fund Fire',
    'PHIPPS CONSERVATORY': 'Phipps Conservatory Fund',
    'AUTO THEFT TF II': 'Auto Theft Task Force II Trust Fund',
    'PANGIS TRUST FUND': 'Pittsburgh Area National Geospatial-Intelligence Agency Trust Fund',
    'VENDING TF-CONTROLLER': 'Vending Trust Fund Controller',
    'ETHICS BOARD TRUST FUND': 'Ethics Board Trust Fund',
    'EARNED INCOME TAX REFUNDS-CITY': 'Earned Income Tax Refunds City',
    'LOCAL LAW ENFORCEMENT': 'Local Law Enforcement Fund',
    'Project Fund 2015 Bond Issue': 'Project Fund 2015 Bond Issue',
    'HIGHWAY SAFETY TF': 'Highway Safety Trust Fund',
    'RENTAL PERMIT TF': 'Rental Permit Trust Fund',
    'OPEN SPACE TRUST FUND': 'Open Space Trust Fund',
    'EARNED INC TAX REFUNDS-SCHOOL': 'Earned Income Tax Refunds School',
    'STIMULUS FUND': 'Stimulus Fund',
    'VENDING TF-COUNCIL': 'Vending Trust Fund Council',
    'OPEB TRUST FUND': 'Other Post-Employment Benefits Trust Fund',
    'LIBERTY AVE BIKE LANE GRANT': 'Liberty Avenue Bike Lane Grant',
    'HPRP': 'Homelessness Prevention and Rapid Re-Housing Program',
    'SWIMMING POOL MAINT TF': 'Swimming Pool Maintenance Trust Fund',
    'COPIER MANAGEMENT & POSTAGE TF': 'Copier Management and Postage Trust Fund',
    'CONTROLLER\'S FIN MAGMT. I.S.': 'Controller\'s Financial Management Information System'
}

df['fund_description'] = df['fund_description'].replace(replace_dict_fund_description)

replace_dict_department_name = {
    'Innovation & Performance': 'Innovation and Performance',
    'DPS-Police': 'Department of Public Safety - Police',
    'DPS-Fire': 'Department of Public Safety - Fire',
    'DPW-Operations': 'Department of Public Works - Operations',
    'Permits Licenses and Inspectio': 'Permits Licenses and Inspection',
    'DPS-Administration': 'Department of Public Safety - Administration',
    'OMI': 'Office of Municipal Investigations',
    'DPS-Animal Care and Control': 'Department of Public Safety - Animal Care and Control',
    'DPW-Administration': 'Department of Public Works - Administration',
    'DPW- Environmental Services': 'Department of Public Works - Environmental Services',
    'DPW - Facilities': 'Department of Public Works - Facilities',
    'Office of  Management and Budg': 'Office of Management and Budget',
    'DPS-Emergency Medical Services': 'Department of Public Safety - Emergency Medical Services',
    'URA Projects': 'Urban Redevelopment Authority Projects',
    'Equipment Leasing Authority': 'Equipment Leasing Authority',
    'Equal Opportunity Review Commi': 'Equal Opportunity Review Committee',
    'Finance, Procurement, Fleet, a': 'Finance, Procurement and Fleet',
    'Non Departmental': 'Non Departmental',
    'DPW-Transportation and Engine': 'Department of Public Works - Transportation and Engine',
    'DPS-Building Inspection': 'Department of Public Safety - Building Inspection',
}

df['department_name'] = df['department_name'].replace(replace_dict_department_name)

# Get the first description found for each cost_center_id
mapping = df.groupby('cost_center_id')['cost_center_description'].first().to_dict()

# Replace all descriptions with the first one found for each ID
df['cost_center_description'] = df['cost_center_id'].map(mapping)

# %%
# Get unique values for each column
for column in df.columns:
    unique_values = df[column].unique()
    print(f"\nUnique values in column '{column}':")
    print(unique_values)
# Out:
# Unique values in column 'id':
# [77837069 77837070 77837071 ... 78454581 78454582 78454583]
#
# Unique values in column 'fund_id':
# [11101 28050 28020 29040 24067 28033 28003 26030 28055 28004 23000 78765
#  26010 24037 78768 32000 24016 26020 28070 28043 28053 40120 29060 75020
#  78160 78170 40017 40018 40119 40019 40118 24063 28085 40001 28045 22000
#  40116 40020 40114 78540 40012 78590 40117 78595 78740 78728 24041 40014
#  24084 78750 24069 40115 24019 24009 24046 28040 28080 40011 24049 24042
#  24800 28015 29080 29065 78400 29070 26050 40013 24040 24081 26060 28067
#  28064 24025 26080 78137 24060 29075 28065 24006 26040 78138 28037 24030
#  24062 78769 78535 78570 24045 24043 24070 28063 78575 29050 78135 29074
#  26090 28060 12881 78722]
#
# Unique values in column 'fund_description':
# ['General Fund' 'Senior Citizens Program Trust Fund'
#  'Equal Employment Opportunity Commission Trust Fund' 'Grants Fund'
#  'Police Secondary Employment Trust Fund' 'Mellon Park Tennis Trust Fund'
#  'Allegheny Regional Asset District Public Works'
#  'Housing and Urban Development Fair Housing Program Trust Fund'
#  'Special Summer Food Service Trust Fund'
#  'Allegheny Regional Asset District Parks' 'Job Training Partnership Act'
#  'Tree Taxing Bodies' 'Community Development Block Grant Fund'
#  'Emergency Medical Services Reimbursement Events Trust Fund'
#  'Three Taxing Bodies Escrow Trust Fund' 'Debt Service Project Fund'
#  'Confiscated Narcotics Proceeds' 'Emergency Shelters Program Trust Fund'
#  'Solid Waste Trust Fund' 'Public Works Trust Fund'
#  'Shade Tree Trust Fund' '2020 Pay-As-You-Go'
#  'Special Parks Program Great Race' 'Workers Compensation Commutations'
#  'Voluntary Employees Beneficiary Association Health Insurance'
#  'Voluntary Employees Beneficiary Association Workers Compensation'
#  'Project Fund 2017 Bond' 'Project Fund 2018 Bond' '2019 Pay-As-You-Go'
#  'Project Fund 2019 Bond' '2018 Pay-As-You-Go'
#  'Pennsylvania Emergency Management Agency and Homeland Security'
#  'Green Initiative Trust Fund' 'Capital Project Fund'
#  'Schenley Park Rink Trust Fund' 'Liquid Fuels Tax' '2016 Pay-As-You-Go'
#  'Project Fund 2020 Bond' 'Transportation Improvement Program Projects'
#  'Fire Escrow' 'Project Fund 2012 Bond' 'Real Estate Tax Refunds City'
#  '2017 Pay-As-You-Go' 'Real Estate Tax Refunds School'
#  'Employee Travel Expense Advance Trust Fund' 'Demolition Trust Fund'
#  'Hazardous Materials Trust Fund' '2014 Pay-As-You-Go'
#  'Crossing Guard Special Events' 'Pittsburgh Code Trust Fund'
#  'Public Safety Training Trust Fund' '2015 Pay-As-You-Go'
#  'Confiscated Non-Narcotics Proceeds' 'Code Trust Fund'
#  'Microfilm Permit Plans Trust Fund'
#  'Pittsburgh Commission on Human Relations Trust Fund'
#  'Verizon Franchise Trust Fund' 'Capital Projects 2006 Bond'
#  'Mounted Police Trust Fund' 'Graffiti Trust Fund'
#  'South Side Parking Enhancement' 'Comcast Franchise Trust Fund'
#  'Frick Park Trust Fund' 'Public Safety Support Trust Fund' 'Escheat Fund'
#  'District 9 Crime Prevention'
#  'Housing Opportunities for Persons With AIDS' '2013 Pay-As-You-Go'
#  'Federal Task Force Trust Fund'
#  "York County Planning Commission Mayor's Youth Initiative Trust Fund"
#  'Appalachian Regional Commission' 'Workforce Development Fund'
#  'Stormwater Management Trust Fund'
#  'Drug Abuse Resistance Education Trust Fund'
#  'Brownfield Economic Development Fund'
#  'Other Post-Employment Benefits Trust Fund Police'
#  'Operation Weed and Seed Fund' 'Facilities Trust Fund'
#  'Wayfinders Signage Trust Fund' 'Criminal Intelligence Fund'
#  'State Emergency Shelter Program'
#  'Other Post-Employment Benefits Trust Fund Fire'
#  'Phipps Conservatory Fund' 'Auto Theft Task Force II Trust Fund'
#  'Pittsburgh Area National Geospatial-Intelligence Agency Trust Fund'
#  'Vending Trust Fund Controller' 'Ethics Board Trust Fund'
#  'Earned Income Tax Refunds City' 'Local Law Enforcement Fund'
#  'Highway Safety Trust Fund' 'Rental Permit Trust Fund'
#  'Open Space Trust Fund' 'Earned Income Tax Refunds School'
#  'Stimulus Fund' 'Other Post-Employment Benefits Trust Fund'
#  'Liberty Avenue Bike Lane Grant'
#  'Homelessness Prevention and Rapid Re-Housing Program'
#  'Swimming Pool Maintenance Trust Fund'
#  'Copier Management and Postage Trust Fund'
#  "Controller's Financial Management Information System"]
#
# Unique values in column 'department_id':
# [103 107 230 250 420 500 101 112 102 105 106 108 109 110 130 210 240 280
#  410 430 450 600 400 122 220 820 840 183 121 440 270]
#
# Unique values in column 'department_name':
# ['Innovation and Performance' 'Department of Finance'
#  'Department of Public Safety - Police'
#  'Department of Public Safety - Fire'
#  'Department of Public Works - Operations' 'Parks and Recreation'
#  'City Council' 'City Clerk' "Mayor's Office" 'Human Relations Commission'
#  "Controller's Office" 'Department of Law' 'Personnel/Civil Service'
#  'Department of City Planning' 'Permits Licenses and Inspection'
#  'Department of Public Safety - Administration'
#  'Office of Municipal Investigations'
#  'Department of Public Safety - Animal Care and Control'
#  'Department of Public Works - Administration'
#  'Department of Public Works - Environmental Services'
#  'Department of Public Works - Facilities' 'Mobility and Infrastructure'
#  'Public Works' 'Office of Management and Budget'
#  'Department of Public Safety - Emergency Medical Services'
#  'Urban Redevelopment Authority Projects' 'Equipment Leasing Authority'
#  'Equal Opportunity Review Committee' 'Finance, Procurement and Fleet'
#  'Department of Public Works - Transportation and Engine'
#  'Department of Public Safety - Building Inspection']
#
# Unique values in column 'cost_center_id':
# [    103000     107000     230000 ... 4029400023 8425589910 2329400043]
#
# Unique values in column 'cost_center_description':
# ['INNOVATION & PERFORMANCE' 'FINANCE' 'PS - POLICE BUREAU' ...
#  'EAST LIBERTY TRID PLANNING' 'DCED-CITY BUSINESS DISTRICT IM'
#  'USDOT/MOTOR SAFETY 2']
#
# Unique values in column 'general_ledger_date':
# ['31/12/2020' '30/12/2020' '29/12/2020' ... '5/1/2012' '4/1/2012'
#  '3/1/2012']
#
# Unique values in column 'amount':
# [ 1.5439800e+03  4.4539600e+03  1.9756000e+02 ...  1.6920380e+04
#   1.0938280e+05 -2.7009139e+05]
#
# Unique values in column 'ledger_code':
# [5 4 8]
#
# Unique values in column 'ledger_description':
# ['Expenses' 'Revenues']

# %% [markdown]
# ## Check first and last date of entry recorded in dataset

# %%
# Convert 'general_ledger_date' to datetime if it's not already
df['general_ledger_date'] = pd.to_datetime(df['general_ledger_date'])

# Find the first date (minimum date)
first_date = df['general_ledger_date'].min()

# Find the last date (maximum date)
last_date = df['general_ledger_date'].max()

# Print the results
print(f"First date: {first_date}")
print(f"Last date: {last_date}")
# Out:
# First date: 2012-01-03 00:00:00
# Last date: 2020-12-31 00:00:00
# C:\Users\User\AppData\Local\Temp\ipykernel_24000\1323043655.py:2: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['general_ledger_date'] = pd.to_datetime(df['general_ledger_date'])

# %%
# Function to standardize the 'fund_description' column
def standardize_fund_description(fund_description):
    return (fund_description
            .replace('-', '_')
            .replace(' ', '_')
            .replace('.', '')
            .replace('\'', '')
            .replace('/', '')
            .replace('&', 'AND')
            .upper())

# Apply the function to the 'fund_description' column
df['fund_description_key'] = df['fund_description'].apply(standardize_fund_description)

# Dictionary to map old values to new ones
replace_dict_fund_description_key = {
    'DEBT_SERVICE__PROJ_FUND': 'DEBT_SERVICE_PROJ_FUND',
    'CAP_PROJ___PROJ_FUND': 'CAP_PROJ_PROJ_FUND',
    'REAL_ESTATE_TAX_REFUNDS___CITY': 'REAL_ESTATE_TAX_REFUNDS_CITY',
    'CAPITAL_PROJECTS___2006_BOND': 'CAPITAL_PROJECTS_2006_BOND'
}

# Apply the replacements
df['fund_description_key'] = df['fund_description_key'].replace(replace_dict_fund_description_key)

column = 'fund_description_key'
unique_values = df[column].unique()
print(f"\nUnique values in column '{column}':")
for i in unique_values:
    print(i)
# Out:
# Unique values in column 'fund_description_key':
# GENERAL_FUND
# SENIOR_CITIZENS_PROGRAM_TRUST_FUND
# EQUAL_EMPLOYMENT_OPPORTUNITY_COMMISSION_TRUST_FUND
# GRANTS_FUND
# POLICE_SECONDARY_EMPLOYMENT_TRUST_FUND
# MELLON_PARK_TENNIS_TRUST_FUND
# ALLEGHENY_REGIONAL_ASSET_DISTRICT_PUBLIC_WORKS
# HOUSING_AND_URBAN_DEVELOPMENT_FAIR_HOUSING_PROGRAM_TRUST_FUND
# SPECIAL_SUMMER_FOOD_SERVICE_TRUST_FUND
# ALLEGHENY_REGIONAL_ASSET_DISTRICT_PARKS
# JOB_TRAINING_PARTNERSHIP_ACT
# TREE_TAXING_BODIES
# COMMUNITY_DEVELOPMENT_BLOCK_GRANT_FUND
# EMERGENCY_MEDICAL_SERVICES_REIMBURSEMENT_EVENTS_TRUST_FUND
# THREE_TAXING_BODIES_ESCROW_TRUST_FUND
# DEBT_SERVICE_PROJECT_FUND
# CONFISCATED_NARCOTICS_PROCEEDS
# EMERGENCY_SHELTERS_PROGRAM_TRUST_FUND
# SOLID_WASTE_TRUST_FUND
# PUBLIC_WORKS_TRUST_FUND
# SHADE_TREE_TRUST_FUND
# 2020_PAY_AS_YOU_GO
# SPECIAL_PARKS_PROGRAM_GREAT_RACE
# WORKERS_COMPENSATION_COMMUTATIONS
# VOLUNTARY_EMPLOYEES_BENEFICIARY_ASSOCIATION_HEALTH_INSURANCE
# VOLUNTARY_EMPLOYEES_BENEFICIARY_ASSOCIATION_WORKERS_COMPENSATION
# PROJECT_FUND_2017_BOND
# PROJECT_FUND_2018_BOND
# 2019_PAY_AS_YOU_GO
# PROJECT_FUND_2019_BOND
# 2018_PAY_AS_YOU_GO
# PENNSYLVANIA_EMERGENCY_MANAGEMENT_AGENCY_AND_HOMELAND_SECURITY
# GREEN_INITIATIVE_TRUST_FUND
# CAPITAL_PROJECT_FUND
# SCHENLEY_PARK_RINK_TRUST_FUND
# LIQUID_FUELS_TAX
# 2016_PAY_AS_YOU_GO
# PROJECT_FUND_2020_BOND
# TRANSPORTATION_IMPROVEMENT_PROGRAM_PROJECTS
# FIRE_ESCROW
# PROJECT_FUND_2012_BOND
# REAL_ESTATE_TAX_REFUNDS_CITY
# 2017_PAY_AS_YOU_GO
# REAL_ESTATE_TAX_REFUNDS_SCHOOL
# EMPLOYEE_TRAVEL_EXPENSE_ADVANCE_TRUST_FUND
# DEMOLITION_TRUST_FUND
# HAZARDOUS_MATERIALS_TRUST_FUND
# 2014_PAY_AS_YOU_GO
# CROSSING_GUARD_SPECIAL_EVENTS
# PITTSBURGH_CODE_TRUST_FUND
# PUBLIC_SAFETY_TRAINING_TRUST_FUND
# 2015_PAY_AS_YOU_GO
# CONFISCATED_NON_NARCOTICS_PROCEEDS
# CODE_TRUST_FUND
# MICROFILM_PERMIT_PLANS_TRUST_FUND
# PITTSBURGH_COMMISSION_ON_HUMAN_RELATIONS_TRUST_FUND
# VERIZON_FRANCHISE_TRUST_FUND
# CAPITAL_PROJECTS_2006_BOND
# MOUNTED_POLICE_TRUST_FUND
# GRAFFITI_TRUST_FUND
# SOUTH_SIDE_PARKING_ENHANCEMENT
# COMCAST_FRANCHISE_TRUST_FUND
# FRICK_PARK_TRUST_FUND
# PUBLIC_SAFETY_SUPPORT_TRUST_FUND
# ESCHEAT_FUND
# DISTRICT_9_CRIME_PREVENTION
# HOUSING_OPPORTUNITIES_FOR_PERSONS_WITH_AIDS
# 2013_PAY_AS_YOU_GO
# FEDERAL_TASK_FORCE_TRUST_FUND
# YORK_COUNTY_PLANNING_COMMISSION_MAYORS_YOUTH_INITIATIVE_TRUST_FUND
# APPALACHIAN_REGIONAL_COMMISSION
# WORKFORCE_DEVELOPMENT_FUND
# STORMWATER_MANAGEMENT_TRUST_FUND
# DRUG_ABUSE_RESISTANCE_EDUCATION_TRUST_FUND
# BROWNFIELD_ECONOMIC_DEVELOPMENT_FUND
# OTHER_POST_EMPLOYMENT_BENEFITS_TRUST_FUND_POLICE
# OPERATION_WEED_AND_SEED_FUND
# FACILITIES_TRUST_FUND
# WAYFINDERS_SIGNAGE_TRUST_FUND
# CRIMINAL_INTELLIGENCE_FUND
# STATE_EMERGENCY_SHELTER_PROGRAM
# OTHER_POST_EMPLOYMENT_BENEFITS_TRUST_FUND_FIRE
# PHIPPS_CONSERVATORY_FUND
# AUTO_THEFT_TASK_FORCE_II_TRUST_FUND
# PITTSBURGH_AREA_NATIONAL_GEOSPATIAL_INTELLIGENCE_AGENCY_TRUST_FUND
# VENDING_TRUST_FUND_CONTROLLER
# ETHICS_BOARD_TRUST_FUND
# EARNED_INCOME_TAX_REFUNDS_CITY
# LOCAL_LAW_ENFORCEMENT_FUND
# HIGHWAY_SAFETY_TRUST_FUND
# RENTAL_PERMIT_TRUST_FUND
# OPEN_SPACE_TRUST_FUND
# EARNED_INCOME_TAX_REFUNDS_SCHOOL
# STIMULUS_FUND
# OTHER_POST_EMPLOYMENT_BENEFITS_TRUST_FUND
# LIBERTY_AVENUE_BIKE_LANE_GRANT
# HOMELESSNESS_PREVENTION_AND_RAPID_RE_HOUSING_PROGRAM
# SWIMMING_POOL_MAINTENANCE_TRUST_FUND
# COPIER_MANAGEMENT_AND_POSTAGE_TRUST_FUND
# CONTROLLERS_FINANCIAL_MANAGEMENT_INFORMATION_SYSTEM

# %%
def standardize_department_name(department_name):
    return (department_name
            .replace('-', '_')
            .replace(' ', '_')
            .replace('.', '')
            .replace('\'', '')
            .replace('/', '_AND_')
            .replace('&', 'AND')
            .upper())

df['department_name_key'] = df['department_name'].apply(standardize_department_name)

replace_dict_department_name_key = {
    'DEPARTMENT_OF_PUBLIC_SAFETY___POLICE': 'DEPARTMENT_OF_PUBLIC_SAFETY_POLICE',
    'DEPARTMENT_OF_PUBLIC_SAFETY___FIRE': 'DEPARTMENT_OF_PUBLIC_SAFETY_FIRE',
    'DEPARTMENT_OF_PUBLIC_WORKS___OPERATIONS': 'DEPARTMENT_OF_PUBLIC_WORKS_OPERATIONS',
    'DEPARTMENT_OF_PUBLIC_SAFETY___ADMINISTRATION': 'DEPARTMENT_OF_PUBLIC_SAFETY_ADMINISTRATION',
    'DEPARTMENT_OF_PUBLIC_SAFETY___ANIMAL_CARE_AND_CONTROL': 'DEPARTMENT_OF_PUBLIC_SAFETY_ANIMAL_CARE_AND_CONTROL',
    'DEPARTMENT_OF_PUBLIC_WORKS___ADMINISTRATION': 'DEPARTMENT_OF_PUBLIC_WORKS_ADMINISTRATION',
    'DEPARTMENT_OF_PUBLIC_WORKS___ENVIRONMENTAL_SERVICES': 'DEPARTMENT_OF_PUBLIC_WORKS_ENVIRONMENTAL_SERVICES',
    'DEPARTMENT_OF_PUBLIC_WORKS___FACILITIES': 'DEPARTMENT_OF_PUBLIC_WORKS_FACILITIES',
    'DEPARTMENT_OF_PUBLIC_SAFETY___EMERGENCY_MEDICAL_SERVICES': 'DEPARTMENT_OF_PUBLIC_SAFETY_EMERGENCY_MEDICAL_SERVICES',
    'DEPARTMENT_OF_PUBLIC_WORKS___TRANSPORTATION_AND_ENGINE': 'DEPARTMENT_OF_PUBLIC_WORKS_TRANSPORTATION_AND_ENGINE',
    'DEPARTMENT_OF_PUBLIC_SAFETY___BUILDING_INSPECTION': 'DEPARTMENT_OF_PUBLIC_SAFETY_BUILDING_INSPECTION',
    'FINANCE,_PROCUREMENT_AND_FLEET': 'FINANCE_PROCUREMENT_AND_FLEET'
}

df['department_name_key'] = df['department_name_key'].replace(replace_dict_department_name_key)

column = 'department_name_key'
unique_values = df[column].unique()
print(f"\nUnique values in column '{column}':")
for i in unique_values:
    print(i)
# Out:
# Unique values in column 'department_name_key':
# INNOVATION_AND_PERFORMANCE
# DEPARTMENT_OF_FINANCE
# DEPARTMENT_OF_PUBLIC_SAFETY_POLICE
# DEPARTMENT_OF_PUBLIC_SAFETY_FIRE
# DEPARTMENT_OF_PUBLIC_WORKS_OPERATIONS
# PARKS_AND_RECREATION
# CITY_COUNCIL
# CITY_CLERK
# MAYORS_OFFICE
# HUMAN_RELATIONS_COMMISSION
# CONTROLLERS_OFFICE
# DEPARTMENT_OF_LAW
# PERSONNEL_AND_CIVIL_SERVICE
# DEPARTMENT_OF_CITY_PLANNING
# PERMITS_LICENSES_AND_INSPECTION
# DEPARTMENT_OF_PUBLIC_SAFETY_ADMINISTRATION
# OFFICE_OF_MUNICIPAL_INVESTIGATIONS
# DEPARTMENT_OF_PUBLIC_SAFETY_ANIMAL_CARE_AND_CONTROL
# DEPARTMENT_OF_PUBLIC_WORKS_ADMINISTRATION
# DEPARTMENT_OF_PUBLIC_WORKS_ENVIRONMENTAL_SERVICES
# DEPARTMENT_OF_PUBLIC_WORKS_FACILITIES
# MOBILITY_AND_INFRASTRUCTURE
# PUBLIC_WORKS
# OFFICE_OF_MANAGEMENT_AND_BUDGET
# DEPARTMENT_OF_PUBLIC_SAFETY_EMERGENCY_MEDICAL_SERVICES
# URBAN_REDEVELOPMENT_AUTHORITY_PROJECTS
# EQUIPMENT_LEASING_AUTHORITY
# EQUAL_OPPORTUNITY_REVIEW_COMMITTEE
# FINANCE_PROCUREMENT_AND_FLEET
# DEPARTMENT_OF_PUBLIC_WORKS_TRANSPORTATION_AND_ENGINE
# DEPARTMENT_OF_PUBLIC_SAFETY_BUILDING_INSPECTION

# %%
# Function to standardize the 'cost_center_description' column
def standardize_cost_center_description(cost_center_description):
    return (cost_center_description
            .replace('-', '_')
            .replace(' ', '_')
            .replace('.', '')
            .replace('\'', '')
            .replace('/', '')
            .replace('&', 'AND')
            .replace('__', '_')
            .replace('___', '_')
            .upper())

# Apply the function to the 'cost_center_description' column
df['cost_center_description_key'] = df['cost_center_description'].apply(standardize_cost_center_description)

# # Dictionary to map old values to new ones
# replace_dict_fund_description_key = {
#     'DEBT_SERVICE__PROJ_FUND': 'DEBT_SERVICE_PROJ_FUND',
#     'CAP_PROJ___PROJ_FUND': 'CAP_PROJ_PROJ_FUND',
#     'REAL_ESTATE_TAX_REFUNDS___CITY': 'REAL_ESTATE_TAX_REFUNDS_CITY',
#     'CAPITAL_PROJECTS___2006_BOND': 'CAPITAL_PROJECTS_2006_BOND'
# }

# Apply the replacements
# df['fund_description_key'] = df['fund_description_key'].replace(replace_dict_fund_description_key)

column = 'cost_center_description_key'
unique_values = df[column].unique()
print(f"\nUnique values in column '{column}':")
for i in unique_values:
    print(i)
# Out:
# Unique values in column 'cost_center_description_key':
# INNOVATION_AND_PERFORMANCE
# FINANCE
# PS__POLICE_BUREAU
# PS__FIRE_BUREAU
# PW_BUREAU_OF_PW_OPERATIONS
# PARKS_AND_RECREATION
# CITY_COUNCIL
# CITY_CLERK
# MAYORS_OFFICE
# BUREAU_OF_NEIGHBORHOOD_EMPOWER
# OFFICE_OF_MANAGEMENT_AND_BUDGE
# HUMAN_RELATIONS_COMM
# CITY_CONTROLLER
# LAW
# ETHICS_BOARD
# HUMAN_RESOURCESCIVIL_SERVICE
# CITY_PLANNING
# PERMITS_LICENSES_AND_INSPECTIO
# PS__ADMIN_AND_SUPPORT_SERVICE
# OFFICE_OF_MUNICIPAL_INVESTIGAT
# PS__BUREAU_OF_ANIMAL_CARE_AND
# PW_BUREAU_OF_ADMINISTRATION
# PW_ENVIRONMENTAL_SERVICES
# BUREAU_OF_FACILITIES
# MOBILITY_AND_INFRASTRUCTURE
# SENIOR_CITEZENS_PROG_TF
# EEOC_TRUST_FUND
# DOMI_HEINZ_GRANT
# POLICE_SECONDARY_EMPL_TF
# DOMESTIC_VIOLENCE_UNIT
# HILLMAN_TRANSPORTATION_FELLOW
# KNIGHT_FOUNDATION_AUTONOMOUS_V
# MELLON_PARK_TENNIS_TF
# ARAD_PUBLIC_WORKS
# BRT_POSITION
# HUD_FAIR_HOUSING_PROG_TF
# SPEC_SUM_FOOD_SERVICE_TF
# ARAD_PARKS
# JTPA
# THREE_TAXING_BODIES_FUND
# CDBG_PERSONNEL
# PS__EMERGENCY_MED_SERVICES
# EMS_REIMB_EVENTS_TRUST_FUND
# 3_TAXING_BODIES_ESCROW_TF
# DEBT_SERVICE__PROJ_FUND
# CONFISCATED_NARC_PROCEEDS
# EMERGENCY_SOLUTIONS_GRANT
# CARES_COVID_FUNDING
# COVID_FEMAPEMA
# CARES_COVID_19_ECHO_FUNDING
# SOLID_WASTE_TF
# IMAGINATION_LIBRARY_BENTER_FOU
# PUBLIC_WORKS_TRUST_FUND
# SHADE_TREE_TRUST_FUND
# TRAFFIC_SAFETY_GRANT_18_19
# AMMON_REC_CENTER_REC2TECH_REMO
# SPECIAL_EVENTS_TRUST_FUND
# WORKERS_COMP_COMMUTATIONS
# VEBA_HEALTH_INSURANCE
# VEBA_WORKERS_COMP
# PARK_RECONSTRUCTION_PROGRAM
# HALC_GREENFIELD
# 412_BLVD_(SHARED)
# RAD_PARKS__HIGHLAND_PARK_SUPE
# HALC_BRIGHTON_HEIGHTS
# FORWARD_AVE_SLOPE_IMPROVEMENTS
# SPORT_FACILITY_IMPROVEMENTS
# PARK_RECONSTRUCTION
# PEMA_AND_HOMELAND_SECURITY_TF
# OWNER_OCCUPIED_HOUSING_REHABIL
# EMERGENCY_SMALL_BUSINESS_SUPPO
# HOUSING_STABILIZATION_PROGRAM
# GREEN_INITIATIVE_TRUST_FUND
# CITY_FARMS
# SCHENLEY_PARK_RINK_TF
# LIQUID_FUELS_TAX
# BAXTER_PLAYGROUND__EQUIPMENT
# FACILITY_IMPROVEMENTS
# FACILITY_IMPROVEMENTS__CITY_F
# POLICE_ZONE_5__RELOCATION
# CDBG_ADMINISTRATION
# ELIZABETH_SETON_CENTER
# HOUSING_AND_ECONOMIC_DEVELOPME
# SHADY_AND_WILKINS__INTERSECTION
# PHASE_1_STREET_AND_SIGNAL_IMPR
# CBD_SIGNALS,_PHASE_2
# STEP_REPAIR_AND_REPLACEMENT
# UPGRADES_TO_CITY_STEPS
# WEST_OHIO_STREET_BRIDGE
# HAZARDOUS_MATERIAL_RESPONSE_EQ
# MCBRIDE_DEK_HOCKEY_RELOCATION
# FACILITY_IMPROVEMENTS__SPORTS
# CHADWICK__COURT_UPGRADES
# LOWRIE_STREET_BRIDGE__CONSTRU
# UPPER_GREENLEAF__SLOPE_IMPROV
# CONCRETE,_BRICK,_BLOLCKSTONE
# HALC_HOMEWOOD
# FIRE_ESCROW
# EAST_END_COOPERATIVE_MINISTRY
# SOUTH_SIDE_NEIGHBORHOOD_STREET
# CHARLES_ANDERSON_BRIDGE
# CBD_SIGNAL_UPGRADES_PHASE_III
# FINAL_MILE_BIKE_PROJECTS__CON
# UPTOWN_PARTNERS_OF_PITTSBURGH
# COMMUNITY_BASED_ORGANIZATIONS
# BEECHVIEW_REVITALIZATION_ADVIS
# ACH_CLEAR_PATHWAYS
# ELLIOTT_WEST_END_ATHLETIC_ASSO
# BIRMINGHAM_FOUNDATIONWEST_END
# PITTSBURGH_PARTNERSHIP_FOR_NEI
# 31ST_WARD_COMMUNITY_ACTION_GRO
# ECONOMIC_DEVELOPMENT_AND_HOUSI
# FIRING_RANGE_IMPROVEMENTS
# SMALLMAN_STREET_RECONSTRUCTION
# LIBERTY_AVENUE_(HSIP)_PE
# LIBERTY_AVENUE(HISP)__PRELIMI
# BRIDGE_REPAIRS
# SWINBURNE_BRIDGE
# COMPLETE_STREETS
# 18TH_STREET_SIGNAL_UPDATES
# SOUTH_NEGLEY_AVENUE_BRIDGE
# MCFARREN_STREET_(SECOND_AVENUE
# 18TH_STREET_SIGNAL_UPDATES(TIP
# DEMOLITION_OF_CITY_OWNED_PROPE
# PENN_AVENUE_RECONSTRUCTION,_II
# FEMA_COVID_SUPPLEMENTAL
# DPW_4TH_DIVISION_BUILDING
# WEST_OHIO_STREET_BRIDGE_CONSTR
# THADDEUS_STEVENS_SCHOOL_SPECIA
# ARSENAL_PARK_PHASE_1_DESIGN_DO
# CITF_NELSON_MANDELA_SPRAY_FEAT
# NETWORK_UPGRADES
# NEIGHBORHOOD_EMPLOYMENT_CENTER
# NEIGHBORHOOD_EMPLOYMENT_PROG
# CENTER_FOR_EMPLOYMENT_OPPORTUN
# VETERANS_LEADERSHIP_PROGRAM_OF
# BROTHERS_AND_SISTERS_EMERGING
# WATER_FEATURE_UPGRADES
# ELLIOTT_WEST_END_AA
# PRESSLEY_HIGH_RISE_TENANT_COUN
# NORTHVIEW_HEIGHTS_ESTATES_MANO
# PERSAD_CENTER
# MCKINLEY_PLAYGROUND__EQUIPMEN
# AUTO_THEFT_GRANT
# I_579_TIGER
# RACP_GRANTSUBGRANT_AGREEMENT
# DCED_MULTIMODAL_GRANTCOOPERAT
# ADDITIONAL_FUNDS
# POOL_REHABILITATION
# REAL_ESTATE_TAX_REFUNDS_CITY
# STREETSCAPE_AND_INTERSECTION_R
# REAL_ESTATE_TAX_REFUNDS_SCHOOL
# SLOPE_UPGRADES__COWLEY_GOETTM
# WESTWOOD_PARK_FIELD_LIGHT_UPGR
# PARKWOOD_ST_SLOPE_IMPROVEMENT
# LIST_ST_SLOPE_IMPROVEMENTS
# SEMICIR_ST_SLOPE_IMPROVEMENTS
# VISTA_ST__CMCI
# GREENFIELD_AVENUE_BRIDGE
# OAKLAND_PLANNING
# FLEX_BEAM_GUARDRAIL_REPLACEMEN
# TRAFFIC_CALMING_DESIGN_SUPPORT
# WENZELL_AVE_CARNAHAN
# WALNUT_STREET_INTERSECTION_UPG
# CAPITAL_EQUIPMENT_ACQUISITION
# COMPREHENSIVE_PLAN
# EMERALD_VIEW_PARK_MASTER_PLAN
# BITUMINOUS_PAVING
# POTHOLE_PATCHING
# EMP_TRAVEL_EXP_ADV_FUND
# ELIZA_FURNACE_TRAIL_WALL_REPAI
# TRAIL_DEVELOPMENT
# SLOPE_UPGRADES__SECOND_AVE_WA
# DEMOLITION_TF
# CHADWICK__FIELD_LIGHT_UPGRADE
# SMITHFIELD_STREET
# 2019_FED_MOTOR_SAFETY
# HAZARD_MATERIALS_TRUST_FUND
# PRO_WALKPRO_BIKE_MELLON
# RAD_PARKS_RINK_UPGRADES
# WIGHTMAN_PARK__UPGRADES
# FLEX_BEAM_GUIDERAILS_AND_FENCI
# CENTRE_AVE_PRELIMINARY_ENGINEE
# PROJECT_MANAGEMENT_SUPPORT
# POLICE_ZONE_4__UPGRADES
# WENZELL_AVENUE_BRIDGE
# EL_PASO_ST__SLOPE_IMPROVEMENT
# BOB_OCONNOR_GOLF_COURSE_CLUBH
# WAR_MEMORIALS_AND_PUBLIC_ART
# AUTO_THEFT_PREVENTION
# KOREAN_WAR_VETERANS_OF_WESTERN
# PCCD_GUN_VIOLENCE_REDUCTION_19
# CROSSING_GUARDS_SPECIAL_EVENTS
# CRACK_SEALING
# UTILITY_CO_OPS
# DOJ_COVID_FUNDING
# PGH_CODE_TRUST_FUND
# WASHINGTON_BLVD_TRAILDOT
# FACILITY_IMPROVEMENTS__PUBLIC
# WASHINGTON_BOULEVARD_TRAIL
# CRITICAL_SIDEWALK_GAPS
# 40TH_AND_PENN__SIGNAL_UPGRADES
# TROY_HILL_CITIZENS,_INC
# YMCA_ALLEGHENY
# SOUTH_SIDE_PARK_MASTER_PLAN
# PUBLIC_SAFETY_TRAINING_TF
# GUN_VIOLENCE_REDUCTION_GRANT
# CROSSWALK_AND_PAINT_UPGRADES
# SAW_MILL_RUN_REMEDIATION
# EMERGENCY_CLEANUPS
# SLOPE_FAILURE_REMEDIATION
# LANDCARE_PROGRAM_CITY_OWNED_P
# RESIDENTIAL_FACADE_IMPROVEMENT
# CENTRE_AVENUE_REVITALIZATION
# LARIMER_CHOICE_NEIGHBORHOOD
# LANDCARE_PROGRAM__URA_OWNED_P
# ECONOMIC_DEVELOPMENT_AND_HOUSING
# FEMA_HALO_BAILOUT
# ADA_COMPLIANCE
# PUBLIC_SAFETY_AEDS
# FRANKSTOWN_AND_EAST_LIBERTY__SI
# PLAY_AREA_IMPROVEMENTS
# ALLIES_FOR_HEALTH_+_WELLBEING
# ALLEN_PLACE_COMMUNITY_SERVICES
# ALLEN_PLACE
# CONFISCATED_NON_NARC_PROCEEDS
# SAFE_ROUTES_TO_SCHOOL
# SIGNAL_PROJECT_DESIGN_SERVICES
# SMALLMAN_DCED
# WIGHTMAN_PARK_PROJECT
# NEIGHBORHOOD_TRAFFIC_CALMING
# 28TH_STREET_BRIDGE
# CITIES_PROCUREMENT
# PHMC_OAKLAND_INVENTORY
# USTA_MELLON_TENNIS_BUBBLE
# DEP_RECYCLING_GRANT_2019
# SECURITY_CAMERA_INTEGRATION_AN
# SOUTH_SIDE_PARK_PHASE_1_DESIGN
# LOWRIE_ST_STEPS
# CODE_TRUST_FUND
# RECORD_STORAGE_TECHNOLOGY,_AND
# PGH_COMM_ON_HUMAN_TELA_TF
# SHADY_AVE_TRAFFIC_CALMING_STUD
# PLAY_AREA_UPGRADES__NIAGARA_P
# PARK_RECONSTRUCTION_RAD_PARKS
# FIRE_STATION_8__IMPROVEMENTS
# VERIZON_FRANCHISE_TF
# FEMA_FIRE_DETECTION_SYSTEM
# URA_PROJECT_DELIVERY
# HANDICAP_RAMPS
# BALL_FIELD_LIGHTING
# PLAY_AREA_IMPROVEMENT
# HEALTHY_ACTIVE_LIVING_CENTER_P
# LIBERTY_AND_MILLVALE__SIGNAL_UP
# POLICE_TRAFFIC_SERVICES_2018
# FIRE_STATION_8_IMPROVEMENTS
# SAW_MILL_RUN_SALT_DOME
# MONITOR_ST_TO_FORWARD_AVE_TRAI
# FINEVIEW_PLAYGROUND_PLAY_AREA
# AIKEN_AND_CENTRE_PEDESTRIAN_SIGN
# 30TH_STREET_BRIDGE_UPGRADES
# CITY_SIGNAL_UPDATE
# CONTINGENCY_BRIDGE_UPGRADES
# HENDERSON_ST_WALL_IMPROVEMENTS
# EADS_ST__SLOPE_IMPROVEMENTS
# PARK_RECONSTRUCTION_PROG__EC
# DESIGN,_CONSTRUCTION_AND_INSPE
# RAMP_AND_PUBLIC_SIDEWALK
# VISION_ZERO__INTERSECTION_SAF
# COMMISSION_OPER_FAIR_HOUSING
# DESIGN,_CONSTRUCTION,_AND_INSP
# PUBLIC_SIDEWALK_UPGRADES
# PITTSBURGH_EMPLOYMENT_PROGRAM
# GREATER_PITTSBURGH_COMMUNITY_F
# BIDWELL_TRAINING_CENTER
# SAINT_PAULS_BENEVOLENT_AND_MISSI
# CENTER_OF_LIFE
# MACEDONIA_FAMILY_AND_COMMUNITY
# VISION_ZERO__HIGH_CRASH_CORRI
# BAKERY_SQUARE_CONSENT_DE_DPW
# PREMO_ST__SLOPE_IMPROVEMENTS
# TOWNSEND_PARKLET_PARK_UPGRADES
# NEW_BUSINESS_START_UP,_BUSINES
# NEWSUBSTANTIALLY_RENOVATED_RE
# HILLTOP_ALLIANCE
# PGH_COM_SERVICE__SAFETY
# PITTSBURGH_PROJECT
# LANDFORCEPITTSBURGH_CONSERVAT
# CDBG_ADMINISTRATION_OVERALL_AD
# SWINBURNE_ST_SLOPE_IMPROVEMENT
# LOWRIE_STREET_BRIDGE_UPGRADES
# DISTRICT_1_NEIGHBORHOOD_NEEDS
# MCFARREN_STREET_BRIDGE
# ROBERT_E_WILLIAMS_COMMUNITY_C
# GREENFIELD_BRIDGE
# NEIGHBORHHOD_TRAFFIC_CALMIMG
# EARTHEN_VESSELS
# EARTHEN_VESSELS_OUTREACH
# UNION_PROJECT
# REBUILDING_TOGETHER_PITTSBURGH
# THE_PITTSBURGH_FOUNDATION
# MOUNTED_POLICE_TF
# GRAFFITI_TRUST_FUND
# GRANVILLE_PARKLET_PARK_UPGRADE
# BROADWAY_AND_BEECHVIEW_INSTALL
# SPLASH_ZONES
# URBAN_LEAGUE_OF_GREATER_PITTSB
# NAOMIS_PLACE
# BRIGHTWOOD_CIVIC_GROUP
# LAWRENCEVILLE_UNITED
# RECREATION_AND_SENIOR_CENTER_REH
# CHRISTIAN_IMMIGRATION_ADVOCACY
# FLOOD_CONTROL_PROJECTS
# WESTERN_PA_SCHOOL_FOR_BLIND_CH
# PITTSBURGH_COMMUNITY_REINVESTM
# JEREMIAHS_PLACE_PITTSBURGH_RE
# EAST_END_COOPERATIV_MINISTRIES
# BRASHEAR_ASSOCIATIONHENRY_KAU
# PITTSBURGH_ACTION_AGAINST_RAPE
# PGH_COMM_SERV__HUNG_PROG__CC
# PITTSBURGH_MUSICAL_THEATRE
# URBAN_LEAGUE__HOUSING_COUNSEL
# COMMUNITY_HUMAN_SERVICES
# WOMENS_CENTER_AND_SHELTER
# TRADE_INSTITUTE_OF_PITTSBURGH
# HAZELWOOD_INITIATIVE
# BROOKLINE_TEEN_OUTREACH
# KNOXVILLE_LIBRARY_RENOVATION
# FOUR_MILE_RUN
# MCKINLEY_PLAYGROUND__PAVING
# FIRE_STATION_UPGRADES
# BITUMINOUS_PAVING_PROGRAM
# SOUTH_SIDE_PARKING_ENHANCEMENT
# NRPA_SUMMER_FOOD
# MT_WASHINGTON__PRELIMINARY_EN
# ALLEGHENY_LANDING_PARK
# COMCAST_FRANCHISE_TF
# FACILITY_IMPROVEMENTS__RECREA
# GENESIS_RESCUE_TOOLS
# FRICK_PARK_TRUST_FUND
# LOWER_WILLIAM_ST_SLOPE_IMPROVE
# NORTHUMBERLAND_AND_SHADY_INTERSE
# DCED_PPC_FRICK_ENVIROMENTAL
# PUBLIC_SAFETY_SUPPORT_TRUST_FU
# FLEX_BEAM_GUIDERAILS
# CONCRETE,_BRICK,_AND_BLOCKSTON
# ESCHEAT_FUND
# ANGELS_PLACE
# CENTER_FOR_VICTIMS__CRISIS_IN
# CENTER_FOR_VICTIMS_PITTSBURGH
# PA_CLEANWAYS_OF_ALLEGHENY_COUN
# GREATER_PITTSBURGH_LITERACY_CO
# LITERACY_PITTSBURGH
# KINGSLEY_ASSOCIATION
# EAST_END_COOPERATIVE_MINISTRIE
# HEINZ_WESTERN_PA_DATA_CENTER
# DISTRICT_9_CRIME_PREVENTION
# REMEDIATION_OF_CONDEMNED_BUILD
# GLENBURY__WATER_MITIGATION
# CBD_SIGNAL_UPGRADES
# FALLOWFIELD_AVE_SLOPE_IMPROVEM
# FALLOWFIELD_AVE__SLOPE_IMPROV
# MAJOR_DEVELOPMENTS
# CENTER_FOR_INNOVATION_AND_ENTREP
# JEWISH_FAMILY_AND_COMMUNITY_SERV
# LICOLN_PLACE_PRESBYTERIAN_CHUR
# OAKLAND_PLANNING_AND_DEVELOPME
# PREVENTION_POINT_PITTSBURGH
# HOPWA
# CHOICE_NEIGHBORHOOD
# HOMEWOODBRUSHTON_REDEVELOPMEN
# FINEVIEW_CITIZENS_COUNCIL
# ZIONIST_ORGANIZATION_OF_AMERIC
# SHEPARD_WELLNESS_COMMUNITY
# STRONG_WOMEN_STRONG_GIRLS
# PEOPLES_OAKLAND
# LARIMER_CONSENSUS_GROUP
# KING_OF_KINGS_BAPTIST_MINISTRY
# BIKE_INFRASTRUCTURE
# ONEPGH_INTEGRATED_TRAFFIC_SIGN
# PLAYGROUND_ACCESSIBILTY_EQUIPM
# HILLMAN_IMAGINATION_LIBRARY
# KEYSTONE_CARRICK_LIBRARY
# RECREATION_AND_SENIOR_CENTER_R
# PENN_AVENUE_RECONSTRUCTION_I
# HAYS_WOODS_MASTER_PLAN
# HILL_DISTRICT_MASTER_PLAN
# MT_WASHINGTON_LIBRARY
# INTEGRATED_SELF_ASSESSED_BUSIN
# COMPREHENSIVE_REVENUE_MANAGEME
# KITCHEN_OF_GRACE
# SAINT_ANDREWS_LUTHERAN_CHURCH
# NORTHSIDE_COMMUNITY_DEVELOPMEN
# LITTLE_SISTERS_OF_THE_POOR_OF
# SOUTH_SIDE_SLOPE_NEIGHBORHOOD
# PLANNING_AND_MANAGEMENT
# PERRY_HILLTOP_CITIZENS_COUNCIL
# BLOOMFIELD_GARFIELD_CORPORATIO
# BUILDING_MAINTENANCE_PROG_GS
# WESTERN_PA_CONSERVANCY
# NORTHSIDE_YOUTH_ATHLETIC_ASSOC
# NORTHSIDE_PARTNERSHIP
# BREAKING_THE_CHAINS_OF_POVERTY
# BLOOMFIELD_DEVELOPMENT_CORP
# YOUNG_MEN_AND_WOMENS_HEBREW_A
# NEIGHBORHOOD_ACADEMY
# CATHOLIC_YOUTH_ASSOCIATION
# POISE_FOUNDATION_HOPE_FUND
# AUDIBLE_TRAFFIC_SIGNALS_AND_TRAF
# CALIFORNIA_AND_ANTRIM__SIGNAL_U
# SARAH_AND_20TH__SIGNAL_UPGRADES
# STAND_UP_NOW
# READING_IS_FUNDAMENTAL
# PENN_AVENUE_PHASE_II
# PAVING_CONTINGENCY
# GVI
# ARLE_BIGELOW_AND_CENTER_PROJEC
# DEMOLITION_OF_CONDEMED_BUILDIN
# LARGE_PROJECT_CONSTRUCTION_MAN
# LANGLEY_COMMUNITY_ENRICHMENT
# INSURANCE_PAYOUTS
# RESERVE_FOR_2020_BOND
# GRANTMAKERS_OF_WESTERN_PA_FOR
# COMMUNITY_STREETSCAPE_PLANNING
# AUDIBLE_PEDESTRIAN_AND_TRAFFIC
# FIFTH_AND_NEGLEY__SIGNAL_IMPROV
# 412_BLVD_(URA)
# SCHENLEY_ICE_RINK_UPGRADES
# STREET_LIGHTS
# FEDERAL_TASK_FORCE_TF
# OBH_PLANNING_GRANT
# OLIVER_BATH_HOUSE_ARCHITECTURA
# YCPCMAYORS_YOUTH_INIT_TF
# MOONEY_AND_GLADSTONE__WATER_MIT
# VODELI_STREET_WATER_MITIGATION
# VISION_ZERO_HIGH_CRASH_CORRIDO
# BIGELOW_AND_CENTRE__SIGNAL_IMPR
# EAST_CARSON_STREET
# DEP_PERFORMANCE_GRANT
# HARBOR_FOUNDATION_TECH_FOR_JEF
# LIBERTY_AVENUE
# GREATER_PITTSBURGH_ARTS_COUNCI
# SLOPE_FAILURE
# THE_PROMISE_GROUP
# RIVERVIEW_MANOR
# JEWISH_FAMILY_AND_CHILDRENS_SE
# FRIENDSHIP_COMMUNITY_GROUP
# EAST_CARSON_STREET_(PENNDOT)
# PUBLIC_SAFETY_CAMERAS
# DEMOLITION_OF_CONDEMNED_BLDG
# POINT_PARK_UNIVERSITY_PLAY_HOU
# ASSOCIATED_MASTER_PLUMBERS_OF
# SPRING_HILL_CIVIC_LEAGUE_CC
# NEIGHBORHOOD_BUSI_ECON_DEVELOP
# MAJOR_DEVELOPMENT
# JEWISH_FAMILY_AND_CHILDRENS_S
# ROX_PERFORMANCE_ACADEMY
# CARRICK_COMMUNITY_COUNCIL_COM
# DISABLED_AND_PUB_SIDEWALK__EC
# JONCAIRE_STEPS_PENNDOT
# DOT_MON_WHARF
# DISTRICT_4_NEIGHBORHOOD_NEEDS
# POOL_EQUIPMENT_UPGRADES
# MC_FARREN_ST9_MILE_RUN_BRIDGE
# LOCAL_AUTOMATED_RED_LIGHT_ENFO
# AFRO_AMERICAN_MUSIC_INSTITUTE
# THE_OPEN_DOOR
# ARC
# URA_PERSONNEL_ECONOMIC_DEVELOP
# URA_PERSONNEL_HOUSING
# DISTRICT_1_WALLS,_STEPS,_FENCE
# PITTSBURGH_MUSICAL_THEATER
# BLOOMFIELD_PRESRV_AND_HERITAGE
# BLOOMFIELD_CITIZENS_COUNCIL
# JUSTICE_ASSISTANCE_GRANT
# PENNDOT_LOCAL_SHARE
# LIBERTY_AVENUE_SINC_UP
# MT_WASHINGTON_SIDEWALK_RECONST
# WORKFORCE_DEVELOPMENT_FUND
# PERSONNEL_CP
# EQUAL_OPP_REVIEW_COMMISION
# FINANCE_TAX_COLLECTION_AND_COM
# FINANCE__BPFAS
# REC_AND_SENIOR_CENTER_REHAB
# STORMWATER_MANAGEMENT_TRUST_FU
# PHMC_ARCH_INVENTORY
# PAHMC_2017_INVENTORY
# PERSONNEL__CITY_PLANNING
# PGH_PARTNERSHIP_EMPLOY_ADMIN
# MT_WASHINGTON_CDC
# HOUSING_AUTHY_REC_PROG_AND_SR
# PERSONNEL__CP
# COMPREHENSIVE_PLANS
# FRIENDSHIP_CIRCLE
# HIGHER_ACHIEVEMENT_INC
# MELLON_INNOVATION_ROADMAP
# ALTERNATIVE_FUELS_INCENTIVE_GR
# AFIG_ELECTRIC_VEHICLE_PROJECT
# AFIG_CHARGING_STATION
# HEINZ_LANGUAGE_GRANT
# TOWNSEND_PARKLET_DCNR_GRANT
# I_AND_P_SWITCHES
# HILLMAN_INNOVATION_ROADMAP
# STREET_RESURFACING
# MELWOOD_TRAFFIC_CALMING
# SENIOR_COMMUNITY_PROGRAM
# RESIDENTIAL_ACCESSIBILITY_IMPR
# RESIDENTIAL_FACADES_IMPROVED
# URBAN_REDEVELOPMENT_AUTHORITY
# NEWSUBSTANTIALLY_RENOVATED_FO
# SAFE_STREETS,_SMART_CITIES_AWA
# ZELLOUS_HOPE_PROJECT
# MT_WASHINGTON_HTS_ATHLETIC
# GYM_FLOOR_UPGRADES
# SHERADEN_UNITED_METHODIST_KIDZ
# NEIGHBORHOOD_LEARNING_ALLIANCE
# CULTURAL_HERITAGE_PLAN
# DRUG_ABUSE_RESISTANCE_ED_TF
# ENTERPRISE_RESOURCE_PLANNING
# NATURALLY_NORTHSIDE
# PPCBUHL_NATURALLY_NORTHSIDE_2
# GREENFIELD_AVE_STEP_UPGRADES
# HOMEWOOD_SIGN_REIMBURSEMENT
# PIRATES_CAHRITIES_CITISPORTS_Y
# EMERGENCY_SHELTER
# EMERGENCY_SHELTERING
# LIBERTY_AVE_SIGNAL_REIMBURSEME
# CENTER_FOR_INNOVATION_AND_ENTR
# DISTRICT_2_NEIGHBORHOOD_NEEDS
# FIRE_EQUIPMENT_2019
# LANDFORCE
# GARFIELD_JUBILEE_ASSOCIATION
# BIG_BROTHERS_BIG_SISTERS_OF_GR
# CITIZEN_PARTICIPATION
# LINCOLN_PLACE_PRESBYTERIAN
# COMMUNITY_FOOD_BANK
# CITIES_OF_TOMORROW_CHALLENGE
# LIFESPAN,_INC
# CHILDRENS_MUSEUM_OF_PITTSBURG
# HILL_COMMUNITY_DEVELOPMENT_COR
# BROWNSFIELD_ECONOMIC_DEVELOPME
# SUE_MURRAY_PLAYGROUND_IMPROVEM
# AFRICAN_AMERICAN_CHAMBER_OF_CO
# URBAN_LEAGUE_HOUSING_COUNSELIN
# RECONSTRUCTION_OF_FORBES_AVE
# ELIZABETH_PARK_ART_PROJECT
# MACEDONIA_FAMILY_AND_COMMUNITY_E
# MACEDONIA_FACE
# COMPUTER_REACH
# SOUTHSIDE_SLOPES_NEIGHBORHOOD
# YMCA_OF_GREATER_PITTSBURGH
# YMCA_OF_GREATER_PITTSBURGH_HOM
# PENNSYLVANIA_RESOURCES_COUNCIL
# SAINT_PAULS_BENEVOLENT_AND_MISS
# BRIGHTWOOD_CIVIC_GROUP_HOUSING
# PITTSBURGH_MEDIATION_CENTER
# NFL_FOUNDATION
# UPTOWN_PLANNING_STUDY
# TRID_GRANT_URA
# WESTERN_PA_ATHLETIC_LEAGUE
# SHEPHERD_WELLNESS_COMMUNITY
# LITTLE_SISTERS_OF_THE_POOR
# SHEPARD_WELLNESS_CENTER
# OPEB_TRUST_POLICE
# WESTERN_PENNSYLVANIA_CONSERVAN
# BRASHEAR_ASSOCIATION
# BRASHEAR_ASSOC
# ALLEGHENY_CITY_CENTRAL_ASSOCIA
# PITTSBURGH_PARKS_CONSERVANCY
# BRASHEAR_ASSOC_HENRY_KAUF
# LINCOLNPLACE_PRESBYTERIAN_CHUR
# BLOOMFIELD_GARFIELD_CORP
# CENTER_VICT_OF_VIOL_CRIME__MO
# PGH_ACTION_AGAINST_RAPE
# MANCHESTER_CITIZENS_CORPORATIO
# NATL_COUNCIL_OF_JEWISH_WOMEN
# NATIONAL_COUNCIL_ON_JEWISH_WOM
# CONSTRUCTION_MANAGEMENTINSPEC
# PROJECT_MANAGEMENT_SERVICES
# PARK_RANGER_GRANT
# PITTSBURGH_TRADE_INSTITUTE
# COMMUNITY_ALLIANCE_FOR_SPRING
# EAST_ALLEGHENY_COMMUNITY_COUNC
# JEWISH_COMMUNITY_CENTER
# JEWISH_COMMUNITY_CENTER_YOUNG
# ST_MARKS_EVANGELICAL_LUTHERAN
# SMALLMAN_STREET_URA
# ENERGY_INNOVATION_CENTER
# PUBLIC_SCHOOL_DESIGN_STUDY
# SCHOOL_DESIGN_STUDY
# PITTSBURGH_GREENWAYS_DCNR
# PIRATES_CHARITIES_FOR_DEVLIN_F
# PIRATES_CHARITIES_FOR_DINAN_FI
# CITY_ENERGY_PROJECT
# SPLASH_ZONES_PAYGO
# BUILDING_MAINTENANCE_PROGRAM
# 2015_JUSTICE_ASSISTANCE_GRANT
# BROOKLINE_CHRISTIAN_FOOD_PANTR
# PITTSBURGH_COMMUNITY_KITCHEN
# DISTRICT_8_NEIGHBORHOOD_NEEDS
# RECON_FORBES_AVE,_PHASE_1B
# BUILDING_COMMUNITY_TRUST_AND_J
# UPTOWN_PARTNERS
# SLOPE_FAILURE_REMIDIATION
# SLB_RADIO_PRODUCTIONS
# POOL_LINER_UPGRADE_MCBRIDE_POO
# LITTER_CAN_UPGRADES_AND_MONITO
# 75_NEW_LITTER_CANS
# LANDER_ST_SLOPE_IMPROVEMENTS
# TREE_OF_HOPE
# CHILDREN_2_CHAMPIONS
# TREE_OF_HOPE,_INC
# ARTISTIC_BANNER_PROJECT
# SWIMMING_POOL_REHABILITATION
# ENTERPRISE_RESOURCE_PLANNING_S
# SCHENLEY_HEIGHTS_CDC
# LAWRENCEVILLE_CORPORATION
# BLOOMFIELD_DEVELOPMENT_CORPORA
# CENTER_VICTIM_VIOLENT_CRIME_C
# PENN_AVENUE_RECONSTRUCTION
# JEFFERSON_PLAYGROUND_SITEACCE
# JEWISH_ASSOCIATION_ON_AGING
# AUDIBLE_TRAFFIC_SIGNALS
# BOB_OCONNOR_GOLF_COURSE
# ROSEDALE_BLOCK_CLUSTER
# RESERVE_FOR_2019_BOND
# OPERATION_WEED_AND_SEED
# USDEOT_TIGER_II
# EMMAUS_COMMUNITY_OF_PITTSBURGH
# CDBG_ADMINISTRATIVE_COSTS
# DISTRICT_3_NEIGHBORHOOD_NEEDS
# ANDERSON_STREET_UNDERPASS
# BRIDGE_INSPECTION_PROGRAM
# READING_IS_FUNDAMENTAL_PITTSBU
# OAKLAND_PLANNING_AND_DEV_CORP
# BUILDING_BRIDGES_FOR_BUSINESSE
# TO_CATHOLIC_CHARITIES
# BIRMINGHAM_FOUNDATIONMT_WASHI
# MON_WHARF_RIVERLIFE
# HOPE_FOR_TOMORROW
# OAKLAND_BUSINESS_IMPROVEMENT_D
# HAZELWOOD_MASTER_PLAN
# WESTERN_PENNSYLVANIA_SCHOOL_FO
# DEMOLITION_OF_CONDEMNED_BUILDI
# CREEDMOOR_COURT
# BAKERY_SQUARE_CONSENT_DE_DOMI
# NATIONAL_REGISTRY_FOR_LAWRENCE
# FACILITIES_TRUST_FUND
# REC_AND_SEN_CENTER_MAINT
# WAYFINDERS_SIGNAGE_TF
# ENTERPRISE_RESOURCE_CONSULTANT
# FINANCIAL_EMPOWERMENT_CENTERS
# PERSONNEL__URA
# MAINTENANCE_AND_ENHANCE_RECS
# NEIGHBORHOOD_ECONOMIC_DEVELOP
# PORT_SECURITY_GRANT
# PAHMC_ARCHITECTURAL_INVENTORY
# DCNR_MON_WHARF_SWITCHBACK
# DCNR_PAULSON_PARK
# SCHENLEY_PARK_TRAFFIC_SIGNAL
# 420_BOULEVARD_OF_THE_ALLIES
# TRAINING_CENTER_DESIGN_STUDY
# HIGHLAND_AVE_STREETLIGHT_PROJE
# WALL,_STEP_AND_FENCE_PROGRAM
# ARCHITECTURAL_ENGINEERING_SERV
# LIVING_CITIES_STEPS_ASSESSMENT
# PACE
# LARIMER_GREEN_TEAM
# HARTFORD_FIRE_PREVENTION
# ACCOMANDO_COMMUNITY_CENTER
# ECONOMIC_DEVELOPMENT_SOUTH
# CARRICKCOMMUNITY_COUNCIL_COMP
# CARRICK_COMMUNITY_COUNCIL
# SHERADEN_UNITED_METHODIST_CHUR
# OLYMPIA_PARK_DOG_PARK
# STEEL_CITY_BOXING
# RESILIENCE_AMERICORPS
# RECREATION_AND_SENIOR_CENTER_MAI
# ERP_CONSULTANT
# RESERVE_FOR_2018_BOND_ISSUE
# WEST_END_BALLFIELDS
# MANCHESTER_FIELD
# CITY_CLERKS_NEIGHBORHOOD_NEEDS
# NORTH_SIDE_LEADERSHIP_COUNCIL
# DHSFEMA_PORT_SECURITY_GRANT
# PEOPLES_GAS_2017_LYB
# CITY_OF_ASYLUM
# ST_AMBROSE_MANOR
# FOWLER_FIELD
# KENNARD_FIELD
# ROCKEFELLER_100RC
# HEINZ_MULTICULTURAL_LIASON
# PENN_AVENUE,_PHASE_1
# NEIGHBORHOOD_STREET_IMPROVEMEN
# PENN_AVENUE_PHASE_I
# JAG
# PITTSBURGH_AIDS_TASK_FORCE
# ARLINGTON_FOOD_BANK
# CATHOLIC_CHARITIES,_DIOCESE_OF
# DEUTSCHTOWN,_EAST_OHIO_STREET
# VIETNAM_VET_LEADERSHIP_PROGRAM
# CRIMINAL_INTELLIGENCE
# ERP_SYSTEM
# DCED_FIFTHTHIRD_CORRIDOR
# HILL_HOUSE
# HILL_HOUSE_ASSOCIATION
# LAWRENCEVILLE_CORP
# 2016_ASSISTANCE_TO_FIREFIGHTER
# PREVENT_ANOTHER_CRIME_TODAY
# NORTHSIDE_CHRONICLE
# DISABLED_AND_PUBLIC_SIDEWALK_PRO
# TROY_HILL_CITIZENS_COUNCIL
# FINEVIEW_CITIZENS_COUNCIL,_INC
# EAST_ALLEGHENY_COMM_COUNCIL
# INFORMATION_SYSTEMS_MODERNIZAT
# LOWER_BLOOMFIELD_UNITY_COUNCIL
# BEECHVIEW_MERCHANTS_ASSOC
# AMANI_CHRISTIAN_DEVELOPMENT_CO
# BALLFIELD_LIGHTING
# STATE_EMERGENCY_SOLUTIO__2015
# DCED_MON_WHARF
# TRINITY_LUTHERAN_CHURCH
# BEECHVIEW_COMMUNITY_AND_SENIOR
# CARRICK_DAIRY_DISTRICT_STREETS
# FINANCIAL_INCLUSION
# PW__ENGINEERING_AND_CONSTRUCTIO
# WALMART_FOUNDATION_ZONE_5
# 2ND_AVE_BRDG_OVER_9_MILE_RUN
# OPEB_TRUST_FIRE
# PHIPPS_CONSERVATORY
# NEIGHBORHOOD_HOUSING_INITIATIV
# BUILDING_MAINTENCE_PROG
# COMMUNITY_EMPOWERMENT_ASSOCIAT
# SUMMER_YOUTH_EMPOLYMENT
# ST_CLAIR_ATHLETIC_ASSOCIATION
# JEWISH_FAMILY__REFUGEE_SERVIC
# POLISH_HILL_CIVIC_ASSOCIATION
# ST_MICHAELS_FOOD_BANK
# SUMMER_YOUTH_EMPLOYMENT_PROG
# EMS_EQUIPMENT
# SAINT_ROSALIA_FOOD_BANK
# STREET_RESURFACING_PAYGO
# AUTO_THEFT_TF_II
# BROOKLINE_BLVD
# HIGHMARK_SUMMER_YOU_2015
# HEINZ_PERMITTING
# ARCHITECTURAL_INVENTORY
# RESERVE_FOR_CO_40011
# RESERVE_FOR_2012_BOND_ISSUE
# EXPENDITURE_BU_FOR_CAFR
# HIGHWAY_SAFETY_GRANT__PENNDOT
# W_PA_POLICE_ATHLETIC_LEAGUE
# HABITAT_FOR_HUMANITY__HOME_RE
# WOODS_RUN_CARNEGIE_LIBRARY
# NEIGHBORHOOD_STREET_IMPROV
# STRONG_WOMEN,_STRONG_GIRLS
# BUILDING_IMPROVEMENTS_PLAN
# DCNR_EMERALD_VIEW_PARK_GRANT
# CITYWIDE_STREET_LIGHTS
# PANGIS_TRUST_FUND
# VENDING_TF__CONTROLLER
# BUILDING_MAINTENANCE_PROG__GS
# URBAN_KIND_INSTITUTE
# BICYCLE_AND_TRANSPORTATION_PLA
# YMCA_CENTRE_AVE
# BLLOMFIELD_GARFIELD_CORPORATIO
# BEYOND_TRAFFIC:THE_SMART_CITY
# SIGNAGE_AND_WAYFINDING
# OBSERVATORY_HILL,_PERRYSVILLE
# PUBLIC_SAFETY_RADIO_REPLACEMEN
# HEINZ_LED_ASTRONOMICAL_FOOTPRI
# IN_CAR_CAMERA_SYSTEM
# PENN_AVE_DESIGN
# TROY_HILL,_LOWRIE_STREET,_BUSI
# COMMUNITY_ALLIANCESPRING_GARD
# SARAH_HEINZ_HOUSE
# ETHICS_BOARD_TRUST_FUND
# USDOJ_BODY_WORN_CAMERA_GRANT
# PROJECT_MANAGEMENT_AND_ADMINIS
# LEAD_SAFE_FOR_KIDS_SAKE_AWARD
# PENN_AVE_RECONSTRUCTION
# CENTRAL_BAPTIST_CHURCH
# MARION_MANOR
# PHILLIPS_PARK_IMPROVEMENTS
# TAX_REFUNDS_CITY
# YMCA_HAZELWOOD_BRANCH
# YMCA_HAZELWOOD
# YMCA_HOMEWOOD
# ST_JOHN_VIANNEY_PARRISH
# PENNSYLVANIA_CONNECTING_COMMUN
# NLC_NS_ROX_YOUTH_MUSIC
# URBAN_LEAGUE__HUNGER_SERVICES
# ATPA_AUTO_THEFT_PREVENTION
# POLICE_MOUNTED_UNITS
# NLC_WEST_COMMONS_TENNET_COUNCI
# DISTRICT_6_NEIGHBORHOOD_NEEDS
# DOJ_JUSTICE_ASSISTANCE_2014
# DPW_POOL_REHABILITATION
# POOL_REHABILITATION__EC
# FEDERAL_CARRIER_GRANT
# DISTRICT_9_NEIGHBORHOOD_NEEDS
# CITY_CLERKS_OFFICE_MODERNIZE
# PA_HISTORICAL_MUSEUMS
# LINCOLN_PLACE_REC_CENTER
# LINCOLN_PLACE_PARK_RENOVATION
# MON_WHARF_URA
# 2ND_AVENUE_AND_MCFARREN_BRIDGE
# WOODLAND_SHADELAND_HOUSING
# WOODLANDSHADELAND_HOUSING_INI
# JEWISH_FAMILY__CAREER_DEVELOP
# PRESERVE_PGH_NATIONAL_REGISTRY
# PGH_COM_REINVESTMENT_GROUP
# SOUTH_SIDE_COMMUNITY_COUNCIL
# MENTORING_PARTNERSHIP_VISTA_PR
# REBUILDING_TOGETHER_AMERICORPS
# BIG_BROTHERS_BIG_SISTERS
# LYNN_WILLIAMS_HIGH_RISE
# BRASHEAR_ASSOC_HENRY_KAUFMAN
# KABOOM_DCNR
# CENTER_FOR_LIFE
# BEECHVIEW_SENIOR_AND_COMMUNITY
# LAWRENCEVILLE_TECHNOLOGY_GRANT
# HILL_DISTRICT_CONSENSUS_GROUP
# ALLEGHENY_CLEANWAYS
# HOMEWOOD_CONCERNED_CITIZENS_CO
# CATHOLIC_YOUTH_ASSOC_LAWRENCEV
# IMPAIRED_DRIVER_GRANT_PA_DOT
# ELLIOTT_WEST_END_ATHLETIC
# PENNSYLVANIA_WOMEN_WORK
# RESERVE_FOR_2017_BOND_ISSUE
# FIREFIGHTING_EQUIPMENT
# FIRE_FIGHTING_EQUIPMENT
# FIRE_EQUIPMENT
# INNOVATION_FELLOW
# DISTRICT_7_NEIGHBORHOOD_NEEDS
# EMERGENCY_SHELTER__2015
# POLICE_FACILITIES_UPGRADE
# LOCAL_LAW_ENFORCEMENT
# RCAP_BEECHVIEW_SENIOR_CENTER
# POLICE_EQUIPMENT
# PGH_ACTION_AGAINST_RAPE_CC
# BRIGHTON_HRIGHTS_SENIOR_CENTER
# RIVERVIEW_TOWER_APARTMENTS
# NLC_SHEPETSKY_ARMS
# PITTSBURGH_SOCCER_IN_THE_COMMU
# SOUTHSIDE_SLOPES_REPAIRS
# KING_MELLON_ARTWRK_CONSERVATIO
# HILLMAN_CITY_ID
# ARCHITECTURAL_SURVEY_GIS
# CITY_CLERKS_OFFICE_MODERNIZATI
# SCHENLEY_PARK_WESTINGHOUSE_MEM
# LARIMER_GREEN
# MT_WASHINGTON_CDC_QUALITY_OF_L
# PGH_COMM_SERV__HUNG_PROG_CC
# PEOPLES_GAS_2015_LYB
# MT_WASHINGTON_COMM_DEV_CORP
# BLOOMFIELD_CITIZEN_COUNCIL
# ST_ANDREWS_LUTHERAN_CHURCH
# HILLTOP_ALLIANCE_ALLENTOWN_CDC
# COMMISSION_OPER__FAIR_HOUSING
# WOOD_STREET_PUBLIC_SPACE_IMPRO
# TIP_REVOLVING_FUND_2014
# SHERADEN_COMMUNITY_COUNCIL
# LINDEN_SCHOOL_PTO
# CENTER_VICTIM_VIOLENT_CRIME_CC
# GRANDVIEW_LIONS_CLUB
# TRAIL_REPAIRS
# 2013_PGH_SUMMER_YOUTH_EMPLOYME
# HEINZ_LEAN_SIGME_6
# EMERALD_ASHE_BORER
# NEIGHBORHOOD_WORKS_OF_WESTERN
# ALEPH_INSTITUTE
# LIFES_WORK_OF_WESTERN_PABEN
# REFINISH_GYMNASIUM_FLOOR
# YOUNG_MEN_AND_WOMENS_HEBREW
# FIREFIGHTING_PROTECTIVE_CLOTH
# PS__BBI
# BRASHEAR_ASSOCIATION_ARLINGTON
# BRASHEAR_ASSOCHENRY_KAUFMAN
# LUMA_TRAINING_HEINZ
# HIGHWAY_SAFETY_TF
# COMMUNITY_BASED_ORGANIZATION
# NORTHSIDE_LEADERSHIP_CONHISTO
# SWIMMING_POOL_MAINTENANCE
# HEINZ__POLICE_TRAINING_GRANT
# SINC_UP_TRAFFIC_SIGNAL_IMPROVE
# EORC_SOFTWARE
# RECONSTRUCTION_OF_FROBES_AVE
# HDR_FOR_GREENFIELD_AVE_BRIDGE
# PARK_WATER_FOUNTAINS
# REC_AND_SENIOR_CENTER_MAINTENANC
# MAINTENANCE_AND_ENHANCE_REC_S
# SPRINGHILL_SPRING_RESTORATION
# SOUTH_HIGHLAND_AVENUE_BRIDGE
# RENTAL_PERMIT_TF
# BIKE_SHARE_PROGRAM
# PITTSBURGH_BIKE_SHARE
# SOUTH_SIDE_ATHLETIC_ASSOCIATIO
# NORTHSIDE_OLD_TIMERS
# ARTS_FOR_AUTISM_FOUNDATION_OF
# ALLIES_FOR_CHILDREN_AMERICORPS
# BUTTONWOOD_STREET_LOW_VOLUME_R
# NATIONAL_LEAGUE_OF_CITIES
# OPEN_SPACE_TRUST_FUND
# SPRINGHILL_SPRING
# MT_WASHINGTON_CDC_BEECHVIEW
# DEPAUL_ACHOOL_FOR_HEARING_AND
# DEPAUL_SCHOOL_FOR_HEARING_AND
# CONSTRUCTION_DIVISION
# LOWER_HETHS_RUN_ATHLETIC_FIEL
# MY_BROTHERS_KEEPER
# FEMA_RADIOS
# EMERGENCY_SHELTER__2014
# NORTHSIDE_PUBLIC_SAFETY_COUNCI
# ECONOMIC_DEVELOPMENT_AND_DESIG
# MANCHESTER_CITIZENS_CORP
# MULTI_MODAL_TRANSPORTATION_PLA
# PRIME_STAGE_THEATRE
# FEMA_FIREFIGHTERS_TRAINING
# FIREFIGHTING_PROTECTIVE_CLOTHI
# OAK_WILT_GRANT
# PMA_BODY_ARMOUR_AND_BODY_CAMER
# NORTHSIDE_COALITION_FOR_FAIR_H
# TAX_REFUNDS_SCHOOL
# WALL,_STEP,_AND_FENCE_EC
# JEWISH_COMM_CENTER
# BIKE_SHARE_PROGRAM_FOR_PROFIT
# WALL,_STEP_AND_FENCE_PAYGO
# BETHLEHEM_HAVEN
# SQUIRREL_HILL_HEALTH_CENTER
# PROPERTY_MANAGEMENT
# BELTZHOOVER_CIVIC_ASSOCIATION
# ARCHENGINEER_SERVICES
# PCCD_PROJECT_SAFE_NEIGHBORHOOD
# WEST_END_ALLIANCE_COMMUNITY_DE
# FINEVIEW_HOUSING
# PHMC_ARCH_PLANNING_GRANT
# LOVE_YOUR_BLOCK_PROGRAM
# PGH_FOUNDATION_NEIGHBORHOOD_EM
# HILLMAN_FOUNDATION_NEIGHBORHOO
# HEINZ_BNE_SUPPORT
# PROVIDENCE_CONNECTIONSMEETIN
# HEALTHY_START
# TREE_MAINTENANCE_PROGRAM
# MCARDLE_ROADWAY
# FIELD_AUTOMATION_INITIATIVE
# DISTRICT_1_DEMOLITION
# 2015_SUMMER_YOUTH_PGH_FOUNDATI
# HEINZ__PUBLIC_ART
# RECONSTRUCTION_OF_FORBES_AVENU
# LEOLYN_PARKLET_IMPROVEMENT
# HOMEWOOD_CAMERAS
# MCKINLEY_PARK_TRACK
# ECONOMIC_SURVEY:PRESERVATION
# BLOOMFIELD_RECREATION_CENTER
# BLOOMFIELD_DECK_HOCKEY
# ELECTRONIC_DAILY_ACTIVITY_SHEE
# FINANCIAL_LITERACY_PROGRAM
# BUHL_FOUNDATION_NEIGHBORHOOD_E
# HIGHWAY_SAFETY_PROGRAM
# PA_HMC
# BEECHWOOD_BLVDBROWNSHILL_RD
# SOUTH_HIGHLAND_AVE_BRIDGE
# SQUIRREL_HILL_BUSINESS_DISTRIC
# TRAFFIC_IMPROVEMENTS
# YMCA_OF_GREATER_PGH_HAZELWOOD
# LAWRENCEVILLE_CORP_PARKING_SOL
# WEB_BASED_PERMITTING_PROJECT
# EAST_LIBERTY_INFRASTRUCTURE
# NRPA_COMMUNITY_GARDENS_GRANT
# RECREATION_CENTER_WIFI_GRANT
# AMERICAN_DISABILITY_ACT
# PUBLIC_SAFETY_SYSTEMS
# DISTRICT_5_NEIGHBORHOOD_NEEDS
# NORTHSIDE_COALITION_FAIR_HOUSI
# HEINZ_PEDESTRIAN_BIKE_PATH
# PRIME_STAGE_THEATER
# GARFIELD_YOUTH_SPORTS_CO_BLOO
# CHILDRENS_SICKLE_CELL_FOUNDAT
# EASTSIDE_NEIGHBORHOOD_EMPLOYME
# CHILDRENS_MUSEUM
# AMANI_CHRISTIAN_COMMUNITY_DEVE
# WENZELL_AVENUE_RECONSTRUCTION
# PUBLIC_SAFETY_RADIOS
# CITY_COUNCIL_CHAMBERS
# WENZELL_AVE_RECONSTRUCTION
# ALLENTOWN_COMMUNITY_DEVELOPMEN
# STEELWORKERS_TOWER
# CENTER_THAT_CARES
# OAKLAND_COMMUNITY_HEALTH_SERVI
# JERON_X_GRAYSON_CENTER
# BEECHVIEW_MANOR
# YOUTH_PLACESREAM_RECREATION_C
# DEPAUL_SCHOOL
# RADIO_SYSTEM_UPGRADE(DPW)
# CODE_FOR_AMERICA
# SPRING_HILL_CIVIC_LEAGUE__CC
# AUTOMATED_FUEL_DISPENSING_SYST
# EMERGENCY_SHELTER__2013
# HAZELWOOD_MAINT_TASK_FORCE
# MINORITY_AND_WOMEN_EDUCATIONAL
# MINORITY_WOMEN_EDUCATIONAL_LAB
# CATHOLIC_YOUTH_ASSOCBLOOMFIEL
# PITTSBURGH_STRUGGLING_STUDENTS
# WELCOMING_PITTSBURGH_INITIATIV
# DCED_ENERGY_AND_UTILITIES
# MCARDLE_ROADWAY_VIADUCT_#1
# NORTHSIDE_FAIR_HOUSING_COALITI
# EAST_LIBERTY_HOUSING,_INC
# GWENS_GIRLS
# DRESS_FOR_SUCCESS
# STIMULUS_BYRNE_JUSTINCE_ASSIST
# PLISH_HILL_CIVIC_ASSOCIATION
# PARKS_CONSERVANCY_ARSENAL_PARK
# UJAMAA_COLLECTIVE
# AMANI_CHRISTION_COMMUNITY_DEVE
# FINEVIEW_CITIZENS_COUNCIL_CC
# FORBES_AVE_AND_MARKET_STREET
# DHHS_EARLY_RETIREMENT_GRANT
# TRAFFIC_SIGNAL_HARDWARE
# COMMUNITY_BASED_ORG__CP
# RIVERVIEW_COMMUNITYSENIOR_CEN
# YOUTH_PLACES__HURRICANES_YOUT
# CENTRAL_NORTHSIDE_NEIGHBORHOOD
# BROWNS_HILL_ROAD
# YOUTH_PLACES_REAM
# PEMA_FIRE_EQUIPMENT_GRANT
# WIRELESS_NEIGHBORHOODS
# TOMORROWS_FUTURE
# DISTRICT_1_EQUIPMENT
# NEIGHBHD_ECONOMIC_DEVELOPMENT
# HISTORIC_DEUTSCHTOWN_DEV_CORP
# URBAN_LEAGUE_HUNGER_SERVICES_N
# MCARDLE_VIADUCT_#1_CONSTRUCTIO
# DOG_PARKS
# NEIGHBORHOOD_BUSINESS_AND_ECON
# PORTMAN_SLOPE
# FIREFIGHTING_GRANT_MATCHING_FU
# YOUNG_MEN_AND_WOMENS_AFRICAN
# SHOTSPOTTER_PROGRAM
# MASTER_PLAN_31ST_WARD
# WILKSBORO_BRIDGE
# PHILLIPS_PARK_IMPROVEMENT
# OAKWOOD_WALKING_TRAIL
# CARRICK_NEIGHBORHOOD_IMPROVEME
# WENZELL_AVENUE
# PARK_CONSERVANCY_ARSENAL_PARK
# SAINT_MARKS_EVANGELICAL_LUTHE
# TRI_HILL_VALLEY_MEALS_ON_WHEEL
# TRI_VALLEY_MEALS_ON_WHEELS
# THE_WHEEL_MILL
# YMCA_OF_GREATER_PGH_CENTRE_AVE
# LINCOLN_PLACE_RECREATION_CNTR
# HIGHMARK_SUMMER_YOUTH_PROGRAM
# STATE_EMERGENCY_SOLUTIO__2011
# RESPONSIBLE_HOSPITALITY
# GREEN_UP_PITTSBURGH_DCED_URA
# PROPERTY_MANAGEMENT_AND_RELOCATI
# USDOT_FEDERAL_MOTOR_CARRIER_PR
# PARK_RECONSTRUCTION_PROG_EC
# PENNDOT_STRIP_DISTRICT_LAND
# NORTHSIDE_LEADERSHIP_CONFERENC
# SALVATION_ARMY
# INFORMATION_SYSTEMS_MODERN
# BEECHVIEW_RENOVATION
# NEGLEY_AVENUE
# WALL_STEP_AND_FENCE_PROGRAM
# WALL,_STEP_AND_FENCE_EC
# OPERATION_BETTER_BLOCK
# EMERGENCY_SHELTER__2011
# BELTZHOOVER_NBH_COUNCIL
# RECREATION_GRANTS_MATCHING_FUN
# DCNR_TREE_VITALIZE
# SPAY_AND_NEUTER_PROGRAM
# ELEVATOR_REPAIR_AND_MAINTENANCE
# MT_WASHINGTON_COMMUNITY_DEVELO
# BRIGHTWOOD_BUSINESS_DISTRICT
# PROPERTY_MANAGEMENT_AND_RELOCA
# COMMUNITY_DESIGN_CENTER_OF_PIT
# COMMUNITY_DESIGN_CENTER
# PENN_WORKS_LTV_HAZELWOOD
# THE_POISE_FOUNDATION
# ELDER__ADO
# MARILYN_G_RABB_FOUNDATION
# MT_WASHINGTON_CDC_SHILOH_ST
# TRAIL_AND_BIKE_ROUTE_DEVELOPMENT
# LAWRENCEVILLE_BLOOMFIELD_MEALS
# BRIGHTON_HEIGHTS,_CALIFORNIA_A
# BRIGHTON_HEIGHTS_MEALS_ON_WHEE
# COLCOM_FOUND_PRO_WALKBIKE
# RK_MELLON_FOUND_PRO_WALKBIKE
# AUGUST_WILSON_HOME_PROJECT
# HOME_DEPOT_LOVE_YOUR_BLOCK_GRA
# NEIGHBORHOOD_STABILIZATION_PRO
# ZONE_3_POLICE_STATION_RELOCATI
# TWO_LIFT_SYSTEMS_AND_POWER_COTS
# MANCHESTER_ELEMENTARY_PTA
# HEINZ__URBAN_DESIGN
# NORTH_SIDE_COMMUNITY_DEVELOPME
# ELDER_ADO_INC
# CITY_COUNTY_BUILDING
# BRIGHTWOOD_ATHLETIC_ORG
# ACCULT_FOR_JUSTICE,_ACCESS,_P
# HILL_DISTRICT_CDC
# PITTSBURGH_COMMUNITY_SERVICES_
# EMERGENCY_SHELTER__2012
# BROAD_STREET
# EAST_LIBERTY_DEVELOPMENT
# COMMUNITY_EMPOWERMENT
# WESTERN_PA_ATHLETIC_ASSOCIATIO
# STREET_LIGHTING
# MAYORS_OFFICE_NEIGHBORHOOD_NE
# BEECHVIEW_SENIOR_CENTER
# DOJ_COPS_TECH_GRANT_2
# MCARDLE_VIADUCT_#1
# MANCHESTER_YOUTH_DEVELOPMENT
# WALL,_STEP_AND_FENCE__EC
# RENEWAL,_INC
# ARCHITECTURAL_ENG_SERV
# SWIFT_WATER_RESCUE
# COMMUNITY_TECHNICAL_ASSISTANCE
# NEIGHBORHOOD_ECONOMIC_DEVELOPM
# NEIGHBORS_IN_THE_STRIP
# COLCOM_FOUNDATION_DEV_OF_A_COM
# ISAIAH_PROJECT
# CITIES_OF_SERVICE_2
# BROOKLINE_MEALS_ON_WHEELS
# BLOOMFIELD_GARFIELD_CORP_COMMU
# FACILITIES_MAINTENENCE_PROGRAM
# CONCRETE,_BRICK,_AND_BLOCK_STO
# NEIGHBORHOOD_LEGAL_SERVICES
# WARRINGTON_AVENUE_RECONSTRUCTI
# 2012_SUMMER_YOUTH_HIGHMARK
# WESLEY_AME_CHARITIES
# MELLON_PARK_RESTROOM_FACILITY
# SOLAR_AMERICAS_CITIES_GRANT
# 31ST_WARD_COMMUNITY_ACT_GRP
# YMCA
# YMCA_HOMEWOOD_BRANCH
# YOUTH_PLACES
# PA_HISTORICAL_AND_MUSEUM_SOCIE
# BOYS_AND_GIRLS_CLUB
# BROOKLINE_BOULEVARD
# MOVING_LIVES_OF_KIDS_ARTS_CENT
# HOMEWOOD_COMMUNITY_SPORTS
# POLICE_STATION_SECURITY_CAMERA
# POLICE_ZONE_ENTRANCE_RENOVATIO
# FIRE_HOSE_AND_SCBA_PARTS
# CAMERAPORT_SECURITY_PROJECT
# COPS_TECHNOLOGY_PROGRAM_DOJ
# YMCA_CENTER_AVE_BRANCH
# LIVING_MINISTRY
# LEGACY_ARTS_PROJECT
# SURVEY_GRANT_URA
# JEWISH_ASSOC_ON_AGING_MOLLIES
# PA_BEVERAGE_ASSOCIATION
# NORTHSIDE_STALLIONS
# MOTOR_CARRIER_SAFETY_2011
# ARCHENGINEERING_SERVICES
# REFORMED_PRESBYTERIAN_HOME
# ACTION_HOUSING
# EDUCATING_TEENS_ABOUT_HIVAIDS
# BEECHWOOD_BLVD
# CONSUMER_HEALTH_COALITION
# WAR_MEMORIALS
# OPEB_TRUST_FUND
# SWIMMING_POOL_MAINTENENCE
# CITY_OF_PITTSBURGH_RADIO_REPLA
# IMPAIRED_MOTORCYCLE_EDUCATION
# EECBG_STIMULUS_DOE
# HILLTOP_COMM_CHILDRENS_CTR
# RIVER_RESCUE_HOMELAND_SECURITY
# FANCOURT_STREET_BRIDGE_(TIP)
# SHERADEN_UNITED_METHODIST_SUM
# SHERADEN_UNITED_METHODIST
# ARLINGTON_CIVIC_COUNCIL_MEALS
# URBAN_LEAGUE_COUNSELING_PROG
# KEYSTONE_DEVELOPMENT_CENTER
# GREENFIELD_GRANT
# NATIONAL_COUNCIL_FOR_URBAN_PEA
# PLF_AMACHI
# SOUTH_SIDE_SABERS_YOUTH_FOOTB
# SENIOR_FRIENDS
# PORT_SERCURITY_GRANT_2BOATHOU
# HOSPITALITY_ZONE_ECONOMIC_AND
# FEMA_FIRE_PREVENTION
# CITIES_OF_SERVICE
# RK_MELLON_FOUNDATION
# SUMMIT_SCHOOL,_INC
# SOUTHSIDE_ATHLETIC_ASSOC
# FAMILY_RESOURCE_CENTER
# FAMILY_RESOURCES
# A_FOR_THE_PEOPLE_TRAINING_INST
# EAST_END_RAIDERS__KINGSLEY_AS
# EAST_END_RAIDERS_KINGSLEY_ASSO
# ST_AMBROSE_MANOR_VAN
# JEWISH_RESIDENTIAL_SERVICES_LO
# 2012_SUMMER_YOUTH_PITTSBURGH_F
# EAST_LIBERTY__PENN_CIRCLE
# EAST_LIBERT__PENN_CIRCLE
# PGH_COMM_SERVICE_SAFETY
# DCED_SOLAR_ENERGY_PROGRAM
# FANCOURT_STREET_BRIDGE
# DOLLAR_ENERGY_FUND
# DOLLAR_ENERGY_FUND,_INC
# JEWISH_ASSOCIATION_ON_AGING_
# JEWISH_ASSOCIATION_ON_AGING_K
# JEWISH_ASSOCIATION_ON_AGING_S
# JEWISH_COMMUNITY_CENTER_SENIOR
# MINORITY_LABOR_EDUCATION
# URBAN_LEAGUE_HOUSING_COUNCIL
# PARK_RECONSTRUCTION_PROG
# CATHOLIC_CHARITIES_OF_PGH
# MATRESS_FACTORY
# WASHINGTON_HEIGHTS_ATHLETIC_A
# FINEVIEW_CITIZENS_COUNCIL__CC
# HAZELWOOD_MEALS_ON_WHEELS
# BIKE_INFRASTRUCTURES
# MIRYAMS
# CENTRAL_N_SIDE_NBH_COUNCIL
# COALITION_FOR_FAIR_HOUSING
# WALL,_STEP,_AND_FENCE_PROGRAM
# VETERANS_LEADERSHIP_PROGRAM
# PGH_COMM_REINVESTMENT_GROUP
# BUILDING_MAINTENANCE_PROG
# SPLASH_ZONS
# ST_ANDREWS_FOOD_BANK
# LIBERTY_AVENUE_GREEN_BIKE_LANE
# OAKLAND_COMMUNITY_COUNCIL
# NATURAL_GAS_REFUSE_TRUCKS
# CAPITAL_ACQUISITION
# FRIENDSHIP_DEVELOPMENT_ASSOC
# REFINISH_GYMNASIUM_FLOORS
# HIGHMARK_SUMMER_YOUTH
# CDBG_ADMINISTRATION_COSTS
# SOUTH_SIDE_LIBRARY_GRANT
# URBAN_LEAGUE_COUNCIL_PROG
# ARLINGTON_CIVIC_COUNCIL
# SMART_TRID_PLANNING_SOUTH_HILL
# WASHINGTON_HEIGHTS_ATH_ASSOC
# SIDS_ALLIANCE,_PGH_AFFILIATE
# WESTERN_PA_CONSERVANCY__MO
# PA_AFFILIATE_SIDS_ALLIANCE
# ELEVATOR_REPAIR_AND_MAINT
# TREE_PLANTING_PROGRAM_MAYORS
# CHILDRENS_HOME
# STEEL_VALLEY_AUTHORITY_CC
# BELTZHOOVER_NGH_COUNCIL
# PEDA_STREETLIGHT_CONVERSION
# ARLINGTON_MEALS_ON_WHEELS
# EMANUEL_CHRISTIAN_PRESCHOOL
# PGH_COMM_SERV_HUNG_PROG_CC
# TRAIL_EXPANSION__MAYORS
# EAST_END_RAIDERS
# SMALL_SEEDS
# WOMENS_CENTER_AND_SHELTER__MO
# SCHENLEY_HEIGHTS_DEVELOPMENT_P
# BATES_STREETSECOND_AVE_INTERS
# HPRP
# OVERBROOK_TOD_DEVO_DESIGN_STUD
# POISE_FOUNDATION__HOPE_FUND
# OBSERVATORY_HILL,_INC
# OBSERVATORY_HILL
# NORTHVIEW_HEIGHTS_ESTATE_MANOR
# THOMAS_MERTON_CENTER_GARFIELD
# SWIMMING_POOL_MAINT_TF
# BIO_DIESEL_RETROFIT_ACHD
# FAMILY_LINKS
# PUBLIC_SPACE_UPGRADE_OAKLAND
# ST_AMBROSE_MANOR__VAN
# SAINT_AMBROSE_MANOR
# PLF__AMACHI
# NORTH_SHORE_COMMUNITY_ALLIANCE
# ALLEGHENY_YMCA
# HILL_DIST_CONSENSUS_GRPCOMM
# MT_WASHINGTON_CDC_HOUSE_T
# TRAIL_AND_BIKE_DEVELOPMENT
# PENNSYLVANIA_RESOURCE_COUNCIL
# DCED_SECTOR_PLANNING
# BATES_STREET2ND_AVE
# ALLEGHENY_COMMONS_INITIATIVE
# DECENTRALIZATION_OF_BBI_EMPLOY
# PERRY_HILLTOP_CITIZENS_COUNCI
# OAKLAND_PLANNING_AND_DEVELOPMENT
# FREEDOM_UNLIMITED
# SOUTH_SIDE_DOG_PARK
# LAWRENCEVILLE_CORPRELOCATION
# IW_ABEL_PLACE
# SCBA_ASSIST_TO_FIREFIGHTERS
# EAST_CARNEGIE_COMMUNITY_COUNCI
# UNIVERSAL_ST_ACADEMY_COMMUNITY
# COPIER_MANAGEMENT_AND_POSTAGE_TF
# URBAN_LEAGUE
# URBAN_LEAGUE_HOUSING_COUNSELNG
# ST_MATTEWS_FOOD_BANK
# SOUTHSIDE_MARKET_HOUSE
# BLOOMFIELD_BUSINESS_ASSOC
# SOUTHSIDE_ATHLETIC_ASSOCIATION
# NEW_HOPE_FOR_NEIGHBORHOOD_RENE
# SOUTHSIDE_SABERS_YOUTH_FOOTBA
# ALLENTOWN_COMMUNITY_DEVELOP
# HEINZ_CASINO_MEETING_GRANT
# SOUTHSIDE_MARKET
# SCBA_EQUIPMENT
# HILL_DANCE_ACADEMY_THEATRE
# GREATER_PGH_FOOD_BANK
# FINEVIEW_CITIZEN_COUNCIL_HENDE
# EMERGENCY_SHELTER__2010
# AGAPE
# PGH_COM_SERVICE_SAFETY
# JEWISH_FAMILY_AND_CHILDRENS_CEN
# URBAN_LEAGUE_HUNGER
# DCED_BUSINESS_DISTRICT_IMPROV
# BALLFIELD_LIGHT_REPLACEMENT
# MCARDLE_VIADUCT_NO_1
# CONTROLLERS_FIN_MGMT_INFO_SYS
# NORTHSHORE_COMMUNITY_ALLIANCE
# LIFES_WORK_OF_WESTERN_PA
# THREE_RIVERS_HERTG_TRAIL
# EAST_LIBERTY_TRID_PLANNING
# DCED_CITY_BUSINESS_DISTRICT_IM
# USDOTMOTOR_SAFETY_2

# %%
# Function to standardize the 'cost_center_description' column
def standardize_cost_center_description(cost_center_description):
    return (cost_center_description
            .replace('__', '_')
            .replace('___', '_')
            .upper())

# Apply the function to the 'cost_center_description' column
df['cost_center_description_key'] = df['cost_center_description_key'].apply(standardize_cost_center_description)

column = 'cost_center_description_key'
unique_values = df[column].unique()
print(f"\nUnique values in column '{column}':")
for i in unique_values:
    print(i)
# Out:
# Unique values in column 'cost_center_description_key':
# INNOVATION_AND_PERFORMANCE
# FINANCE
# PS_POLICE_BUREAU
# PS_FIRE_BUREAU
# PW_BUREAU_OF_PW_OPERATIONS
# PARKS_AND_RECREATION
# CITY_COUNCIL
# CITY_CLERK
# MAYORS_OFFICE
# BUREAU_OF_NEIGHBORHOOD_EMPOWER
# OFFICE_OF_MANAGEMENT_AND_BUDGE
# HUMAN_RELATIONS_COMM
# CITY_CONTROLLER
# LAW
# ETHICS_BOARD
# HUMAN_RESOURCESCIVIL_SERVICE
# CITY_PLANNING
# PERMITS_LICENSES_AND_INSPECTIO
# PS_ADMIN_AND_SUPPORT_SERVICE
# OFFICE_OF_MUNICIPAL_INVESTIGAT
# PS_BUREAU_OF_ANIMAL_CARE_AND
# PW_BUREAU_OF_ADMINISTRATION
# PW_ENVIRONMENTAL_SERVICES
# BUREAU_OF_FACILITIES
# MOBILITY_AND_INFRASTRUCTURE
# SENIOR_CITEZENS_PROG_TF
# EEOC_TRUST_FUND
# DOMI_HEINZ_GRANT
# POLICE_SECONDARY_EMPL_TF
# DOMESTIC_VIOLENCE_UNIT
# HILLMAN_TRANSPORTATION_FELLOW
# KNIGHT_FOUNDATION_AUTONOMOUS_V
# MELLON_PARK_TENNIS_TF
# ARAD_PUBLIC_WORKS
# BRT_POSITION
# HUD_FAIR_HOUSING_PROG_TF
# SPEC_SUM_FOOD_SERVICE_TF
# ARAD_PARKS
# JTPA
# THREE_TAXING_BODIES_FUND
# CDBG_PERSONNEL
# PS_EMERGENCY_MED_SERVICES
# EMS_REIMB_EVENTS_TRUST_FUND
# 3_TAXING_BODIES_ESCROW_TF
# DEBT_SERVICE_PROJ_FUND
# CONFISCATED_NARC_PROCEEDS
# EMERGENCY_SOLUTIONS_GRANT
# CARES_COVID_FUNDING
# COVID_FEMAPEMA
# CARES_COVID_19_ECHO_FUNDING
# SOLID_WASTE_TF
# IMAGINATION_LIBRARY_BENTER_FOU
# PUBLIC_WORKS_TRUST_FUND
# SHADE_TREE_TRUST_FUND
# TRAFFIC_SAFETY_GRANT_18_19
# AMMON_REC_CENTER_REC2TECH_REMO
# SPECIAL_EVENTS_TRUST_FUND
# WORKERS_COMP_COMMUTATIONS
# VEBA_HEALTH_INSURANCE
# VEBA_WORKERS_COMP
# PARK_RECONSTRUCTION_PROGRAM
# HALC_GREENFIELD
# 412_BLVD_(SHARED)
# RAD_PARKS_HIGHLAND_PARK_SUPE
# HALC_BRIGHTON_HEIGHTS
# FORWARD_AVE_SLOPE_IMPROVEMENTS
# SPORT_FACILITY_IMPROVEMENTS
# PARK_RECONSTRUCTION
# PEMA_AND_HOMELAND_SECURITY_TF
# OWNER_OCCUPIED_HOUSING_REHABIL
# EMERGENCY_SMALL_BUSINESS_SUPPO
# HOUSING_STABILIZATION_PROGRAM
# GREEN_INITIATIVE_TRUST_FUND
# CITY_FARMS
# SCHENLEY_PARK_RINK_TF
# LIQUID_FUELS_TAX
# BAXTER_PLAYGROUND_EQUIPMENT
# FACILITY_IMPROVEMENTS
# FACILITY_IMPROVEMENTS_CITY_F
# POLICE_ZONE_5_RELOCATION
# CDBG_ADMINISTRATION
# ELIZABETH_SETON_CENTER
# HOUSING_AND_ECONOMIC_DEVELOPME
# SHADY_AND_WILKINS_INTERSECTION
# PHASE_1_STREET_AND_SIGNAL_IMPR
# CBD_SIGNALS,_PHASE_2
# STEP_REPAIR_AND_REPLACEMENT
# UPGRADES_TO_CITY_STEPS
# WEST_OHIO_STREET_BRIDGE
# HAZARDOUS_MATERIAL_RESPONSE_EQ
# MCBRIDE_DEK_HOCKEY_RELOCATION
# FACILITY_IMPROVEMENTS_SPORTS
# CHADWICK_COURT_UPGRADES
# LOWRIE_STREET_BRIDGE_CONSTRU
# UPPER_GREENLEAF_SLOPE_IMPROV
# CONCRETE,_BRICK,_BLOLCKSTONE
# HALC_HOMEWOOD
# FIRE_ESCROW
# EAST_END_COOPERATIVE_MINISTRY
# SOUTH_SIDE_NEIGHBORHOOD_STREET
# CHARLES_ANDERSON_BRIDGE
# CBD_SIGNAL_UPGRADES_PHASE_III
# FINAL_MILE_BIKE_PROJECTS_CON
# UPTOWN_PARTNERS_OF_PITTSBURGH
# COMMUNITY_BASED_ORGANIZATIONS
# BEECHVIEW_REVITALIZATION_ADVIS
# ACH_CLEAR_PATHWAYS
# ELLIOTT_WEST_END_ATHLETIC_ASSO
# BIRMINGHAM_FOUNDATIONWEST_END
# PITTSBURGH_PARTNERSHIP_FOR_NEI
# 31ST_WARD_COMMUNITY_ACTION_GRO
# ECONOMIC_DEVELOPMENT_AND_HOUSI
# FIRING_RANGE_IMPROVEMENTS
# SMALLMAN_STREET_RECONSTRUCTION
# LIBERTY_AVENUE_(HSIP)_PE
# LIBERTY_AVENUE(HISP)_PRELIMI
# BRIDGE_REPAIRS
# SWINBURNE_BRIDGE
# COMPLETE_STREETS
# 18TH_STREET_SIGNAL_UPDATES
# SOUTH_NEGLEY_AVENUE_BRIDGE
# MCFARREN_STREET_(SECOND_AVENUE
# 18TH_STREET_SIGNAL_UPDATES(TIP
# DEMOLITION_OF_CITY_OWNED_PROPE
# PENN_AVENUE_RECONSTRUCTION,_II
# FEMA_COVID_SUPPLEMENTAL
# DPW_4TH_DIVISION_BUILDING
# WEST_OHIO_STREET_BRIDGE_CONSTR
# THADDEUS_STEVENS_SCHOOL_SPECIA
# ARSENAL_PARK_PHASE_1_DESIGN_DO
# CITF_NELSON_MANDELA_SPRAY_FEAT
# NETWORK_UPGRADES
# NEIGHBORHOOD_EMPLOYMENT_CENTER
# NEIGHBORHOOD_EMPLOYMENT_PROG
# CENTER_FOR_EMPLOYMENT_OPPORTUN
# VETERANS_LEADERSHIP_PROGRAM_OF
# BROTHERS_AND_SISTERS_EMERGING
# WATER_FEATURE_UPGRADES
# ELLIOTT_WEST_END_AA
# PRESSLEY_HIGH_RISE_TENANT_COUN
# NORTHVIEW_HEIGHTS_ESTATES_MANO
# PERSAD_CENTER
# MCKINLEY_PLAYGROUND_EQUIPMEN
# AUTO_THEFT_GRANT
# I_579_TIGER
# RACP_GRANTSUBGRANT_AGREEMENT
# DCED_MULTIMODAL_GRANTCOOPERAT
# ADDITIONAL_FUNDS
# POOL_REHABILITATION
# REAL_ESTATE_TAX_REFUNDS_CITY
# STREETSCAPE_AND_INTERSECTION_R
# REAL_ESTATE_TAX_REFUNDS_SCHOOL
# SLOPE_UPGRADES_COWLEY_GOETTM
# WESTWOOD_PARK_FIELD_LIGHT_UPGR
# PARKWOOD_ST_SLOPE_IMPROVEMENT
# LIST_ST_SLOPE_IMPROVEMENTS
# SEMICIR_ST_SLOPE_IMPROVEMENTS
# VISTA_ST_CMCI
# GREENFIELD_AVENUE_BRIDGE
# OAKLAND_PLANNING
# FLEX_BEAM_GUARDRAIL_REPLACEMEN
# TRAFFIC_CALMING_DESIGN_SUPPORT
# WENZELL_AVE_CARNAHAN
# WALNUT_STREET_INTERSECTION_UPG
# CAPITAL_EQUIPMENT_ACQUISITION
# COMPREHENSIVE_PLAN
# EMERALD_VIEW_PARK_MASTER_PLAN
# BITUMINOUS_PAVING
# POTHOLE_PATCHING
# EMP_TRAVEL_EXP_ADV_FUND
# ELIZA_FURNACE_TRAIL_WALL_REPAI
# TRAIL_DEVELOPMENT
# SLOPE_UPGRADES_SECOND_AVE_WA
# DEMOLITION_TF
# CHADWICK_FIELD_LIGHT_UPGRADE
# SMITHFIELD_STREET
# 2019_FED_MOTOR_SAFETY
# HAZARD_MATERIALS_TRUST_FUND
# PRO_WALKPRO_BIKE_MELLON
# RAD_PARKS_RINK_UPGRADES
# WIGHTMAN_PARK_UPGRADES
# FLEX_BEAM_GUIDERAILS_AND_FENCI
# CENTRE_AVE_PRELIMINARY_ENGINEE
# PROJECT_MANAGEMENT_SUPPORT
# POLICE_ZONE_4_UPGRADES
# WENZELL_AVENUE_BRIDGE
# EL_PASO_ST_SLOPE_IMPROVEMENT
# BOB_OCONNOR_GOLF_COURSE_CLUBH
# WAR_MEMORIALS_AND_PUBLIC_ART
# AUTO_THEFT_PREVENTION
# KOREAN_WAR_VETERANS_OF_WESTERN
# PCCD_GUN_VIOLENCE_REDUCTION_19
# CROSSING_GUARDS_SPECIAL_EVENTS
# CRACK_SEALING
# UTILITY_CO_OPS
# DOJ_COVID_FUNDING
# PGH_CODE_TRUST_FUND
# WASHINGTON_BLVD_TRAILDOT
# FACILITY_IMPROVEMENTS_PUBLIC
# WASHINGTON_BOULEVARD_TRAIL
# CRITICAL_SIDEWALK_GAPS
# 40TH_AND_PENN_SIGNAL_UPGRADES
# TROY_HILL_CITIZENS,_INC
# YMCA_ALLEGHENY
# SOUTH_SIDE_PARK_MASTER_PLAN
# PUBLIC_SAFETY_TRAINING_TF
# GUN_VIOLENCE_REDUCTION_GRANT
# CROSSWALK_AND_PAINT_UPGRADES
# SAW_MILL_RUN_REMEDIATION
# EMERGENCY_CLEANUPS
# SLOPE_FAILURE_REMEDIATION
# LANDCARE_PROGRAM_CITY_OWNED_P
# RESIDENTIAL_FACADE_IMPROVEMENT
# CENTRE_AVENUE_REVITALIZATION
# LARIMER_CHOICE_NEIGHBORHOOD
# LANDCARE_PROGRAM_URA_OWNED_P
# ECONOMIC_DEVELOPMENT_AND_HOUSING
# FEMA_HALO_BAILOUT
# ADA_COMPLIANCE
# PUBLIC_SAFETY_AEDS
# FRANKSTOWN_AND_EAST_LIBERTY_SI
# PLAY_AREA_IMPROVEMENTS
# ALLIES_FOR_HEALTH_+_WELLBEING
# ALLEN_PLACE_COMMUNITY_SERVICES
# ALLEN_PLACE
# CONFISCATED_NON_NARC_PROCEEDS
# SAFE_ROUTES_TO_SCHOOL
# SIGNAL_PROJECT_DESIGN_SERVICES
# SMALLMAN_DCED
# WIGHTMAN_PARK_PROJECT
# NEIGHBORHOOD_TRAFFIC_CALMING
# 28TH_STREET_BRIDGE
# CITIES_PROCUREMENT
# PHMC_OAKLAND_INVENTORY
# USTA_MELLON_TENNIS_BUBBLE
# DEP_RECYCLING_GRANT_2019
# SECURITY_CAMERA_INTEGRATION_AN
# SOUTH_SIDE_PARK_PHASE_1_DESIGN
# LOWRIE_ST_STEPS
# CODE_TRUST_FUND
# RECORD_STORAGE_TECHNOLOGY,_AND
# PGH_COMM_ON_HUMAN_TELA_TF
# SHADY_AVE_TRAFFIC_CALMING_STUD
# PLAY_AREA_UPGRADES_NIAGARA_P
# PARK_RECONSTRUCTION_RAD_PARKS
# FIRE_STATION_8_IMPROVEMENTS
# VERIZON_FRANCHISE_TF
# FEMA_FIRE_DETECTION_SYSTEM
# URA_PROJECT_DELIVERY
# HANDICAP_RAMPS
# BALL_FIELD_LIGHTING
# PLAY_AREA_IMPROVEMENT
# HEALTHY_ACTIVE_LIVING_CENTER_P
# LIBERTY_AND_MILLVALE_SIGNAL_UP
# POLICE_TRAFFIC_SERVICES_2018
# SAW_MILL_RUN_SALT_DOME
# MONITOR_ST_TO_FORWARD_AVE_TRAI
# FINEVIEW_PLAYGROUND_PLAY_AREA
# AIKEN_AND_CENTRE_PEDESTRIAN_SIGN
# 30TH_STREET_BRIDGE_UPGRADES
# CITY_SIGNAL_UPDATE
# CONTINGENCY_BRIDGE_UPGRADES
# HENDERSON_ST_WALL_IMPROVEMENTS
# EADS_ST_SLOPE_IMPROVEMENTS
# PARK_RECONSTRUCTION_PROG_EC
# DESIGN,_CONSTRUCTION_AND_INSPE
# RAMP_AND_PUBLIC_SIDEWALK
# VISION_ZERO_INTERSECTION_SAF
# COMMISSION_OPER_FAIR_HOUSING
# DESIGN,_CONSTRUCTION,_AND_INSP
# PUBLIC_SIDEWALK_UPGRADES
# PITTSBURGH_EMPLOYMENT_PROGRAM
# GREATER_PITTSBURGH_COMMUNITY_F
# BIDWELL_TRAINING_CENTER
# SAINT_PAULS_BENEVOLENT_AND_MISSI
# CENTER_OF_LIFE
# MACEDONIA_FAMILY_AND_COMMUNITY
# VISION_ZERO_HIGH_CRASH_CORRI
# BAKERY_SQUARE_CONSENT_DE_DPW
# PREMO_ST_SLOPE_IMPROVEMENTS
# TOWNSEND_PARKLET_PARK_UPGRADES
# NEW_BUSINESS_START_UP,_BUSINES
# NEWSUBSTANTIALLY_RENOVATED_RE
# HILLTOP_ALLIANCE
# PGH_COM_SERVICE_SAFETY
# PITTSBURGH_PROJECT
# LANDFORCEPITTSBURGH_CONSERVAT
# CDBG_ADMINISTRATION_OVERALL_AD
# SWINBURNE_ST_SLOPE_IMPROVEMENT
# LOWRIE_STREET_BRIDGE_UPGRADES
# DISTRICT_1_NEIGHBORHOOD_NEEDS
# MCFARREN_STREET_BRIDGE
# ROBERT_E_WILLIAMS_COMMUNITY_C
# GREENFIELD_BRIDGE
# NEIGHBORHHOD_TRAFFIC_CALMIMG
# EARTHEN_VESSELS
# EARTHEN_VESSELS_OUTREACH
# UNION_PROJECT
# REBUILDING_TOGETHER_PITTSBURGH
# THE_PITTSBURGH_FOUNDATION
# MOUNTED_POLICE_TF
# GRAFFITI_TRUST_FUND
# GRANVILLE_PARKLET_PARK_UPGRADE
# BROADWAY_AND_BEECHVIEW_INSTALL
# SPLASH_ZONES
# URBAN_LEAGUE_OF_GREATER_PITTSB
# NAOMIS_PLACE
# BRIGHTWOOD_CIVIC_GROUP
# LAWRENCEVILLE_UNITED
# RECREATION_AND_SENIOR_CENTER_REH
# CHRISTIAN_IMMIGRATION_ADVOCACY
# FLOOD_CONTROL_PROJECTS
# WESTERN_PA_SCHOOL_FOR_BLIND_CH
# PITTSBURGH_COMMUNITY_REINVESTM
# JEREMIAHS_PLACE_PITTSBURGH_RE
# EAST_END_COOPERATIV_MINISTRIES
# BRASHEAR_ASSOCIATIONHENRY_KAU
# PITTSBURGH_ACTION_AGAINST_RAPE
# PGH_COMM_SERV_HUNG_PROG_CC
# PITTSBURGH_MUSICAL_THEATRE
# URBAN_LEAGUE_HOUSING_COUNSEL
# COMMUNITY_HUMAN_SERVICES
# WOMENS_CENTER_AND_SHELTER
# TRADE_INSTITUTE_OF_PITTSBURGH
# HAZELWOOD_INITIATIVE
# BROOKLINE_TEEN_OUTREACH
# KNOXVILLE_LIBRARY_RENOVATION
# FOUR_MILE_RUN
# MCKINLEY_PLAYGROUND_PAVING
# FIRE_STATION_UPGRADES
# BITUMINOUS_PAVING_PROGRAM
# SOUTH_SIDE_PARKING_ENHANCEMENT
# NRPA_SUMMER_FOOD
# MT_WASHINGTON_PRELIMINARY_EN
# ALLEGHENY_LANDING_PARK
# COMCAST_FRANCHISE_TF
# FACILITY_IMPROVEMENTS_RECREA
# GENESIS_RESCUE_TOOLS
# FRICK_PARK_TRUST_FUND
# LOWER_WILLIAM_ST_SLOPE_IMPROVE
# NORTHUMBERLAND_AND_SHADY_INTERSE
# DCED_PPC_FRICK_ENVIROMENTAL
# PUBLIC_SAFETY_SUPPORT_TRUST_FU
# FLEX_BEAM_GUIDERAILS
# CONCRETE,_BRICK,_AND_BLOCKSTON
# ESCHEAT_FUND
# ANGELS_PLACE
# CENTER_FOR_VICTIMS_CRISIS_IN
# CENTER_FOR_VICTIMS_PITTSBURGH
# PA_CLEANWAYS_OF_ALLEGHENY_COUN
# GREATER_PITTSBURGH_LITERACY_CO
# LITERACY_PITTSBURGH
# KINGSLEY_ASSOCIATION
# EAST_END_COOPERATIVE_MINISTRIE
# HEINZ_WESTERN_PA_DATA_CENTER
# DISTRICT_9_CRIME_PREVENTION
# REMEDIATION_OF_CONDEMNED_BUILD
# GLENBURY_WATER_MITIGATION
# CBD_SIGNAL_UPGRADES
# FALLOWFIELD_AVE_SLOPE_IMPROVEM
# FALLOWFIELD_AVE_SLOPE_IMPROV
# MAJOR_DEVELOPMENTS
# CENTER_FOR_INNOVATION_AND_ENTREP
# JEWISH_FAMILY_AND_COMMUNITY_SERV
# LICOLN_PLACE_PRESBYTERIAN_CHUR
# OAKLAND_PLANNING_AND_DEVELOPME
# PREVENTION_POINT_PITTSBURGH
# HOPWA
# CHOICE_NEIGHBORHOOD
# HOMEWOODBRUSHTON_REDEVELOPMEN
# FINEVIEW_CITIZENS_COUNCIL
# ZIONIST_ORGANIZATION_OF_AMERIC
# SHEPARD_WELLNESS_COMMUNITY
# STRONG_WOMEN_STRONG_GIRLS
# PEOPLES_OAKLAND
# LARIMER_CONSENSUS_GROUP
# KING_OF_KINGS_BAPTIST_MINISTRY
# BIKE_INFRASTRUCTURE
# ONEPGH_INTEGRATED_TRAFFIC_SIGN
# PLAYGROUND_ACCESSIBILTY_EQUIPM
# HILLMAN_IMAGINATION_LIBRARY
# KEYSTONE_CARRICK_LIBRARY
# RECREATION_AND_SENIOR_CENTER_R
# PENN_AVENUE_RECONSTRUCTION_I
# HAYS_WOODS_MASTER_PLAN
# HILL_DISTRICT_MASTER_PLAN
# MT_WASHINGTON_LIBRARY
# INTEGRATED_SELF_ASSESSED_BUSIN
# COMPREHENSIVE_REVENUE_MANAGEME
# KITCHEN_OF_GRACE
# SAINT_ANDREWS_LUTHERAN_CHURCH
# NORTHSIDE_COMMUNITY_DEVELOPMEN
# LITTLE_SISTERS_OF_THE_POOR_OF
# SOUTH_SIDE_SLOPE_NEIGHBORHOOD
# PLANNING_AND_MANAGEMENT
# PERRY_HILLTOP_CITIZENS_COUNCIL
# BLOOMFIELD_GARFIELD_CORPORATIO
# BUILDING_MAINTENANCE_PROG_GS
# WESTERN_PA_CONSERVANCY
# NORTHSIDE_YOUTH_ATHLETIC_ASSOC
# NORTHSIDE_PARTNERSHIP
# BREAKING_THE_CHAINS_OF_POVERTY
# BLOOMFIELD_DEVELOPMENT_CORP
# YOUNG_MEN_AND_WOMENS_HEBREW_A
# NEIGHBORHOOD_ACADEMY
# CATHOLIC_YOUTH_ASSOCIATION
# POISE_FOUNDATION_HOPE_FUND
# AUDIBLE_TRAFFIC_SIGNALS_AND_TRAF
# CALIFORNIA_AND_ANTRIM_SIGNAL_U
# SARAH_AND_20TH_SIGNAL_UPGRADES
# STAND_UP_NOW
# READING_IS_FUNDAMENTAL
# PENN_AVENUE_PHASE_II
# PAVING_CONTINGENCY
# GVI
# ARLE_BIGELOW_AND_CENTER_PROJEC
# DEMOLITION_OF_CONDEMED_BUILDIN
# LARGE_PROJECT_CONSTRUCTION_MAN
# LANGLEY_COMMUNITY_ENRICHMENT
# INSURANCE_PAYOUTS
# RESERVE_FOR_2020_BOND
# GRANTMAKERS_OF_WESTERN_PA_FOR
# COMMUNITY_STREETSCAPE_PLANNING
# AUDIBLE_PEDESTRIAN_AND_TRAFFIC
# FIFTH_AND_NEGLEY_SIGNAL_IMPROV
# 412_BLVD_(URA)
# SCHENLEY_ICE_RINK_UPGRADES
# STREET_LIGHTS
# FEDERAL_TASK_FORCE_TF
# OBH_PLANNING_GRANT
# OLIVER_BATH_HOUSE_ARCHITECTURA
# YCPCMAYORS_YOUTH_INIT_TF
# MOONEY_AND_GLADSTONE_WATER_MIT
# VODELI_STREET_WATER_MITIGATION
# VISION_ZERO_HIGH_CRASH_CORRIDO
# BIGELOW_AND_CENTRE_SIGNAL_IMPR
# EAST_CARSON_STREET
# DEP_PERFORMANCE_GRANT
# HARBOR_FOUNDATION_TECH_FOR_JEF
# LIBERTY_AVENUE
# GREATER_PITTSBURGH_ARTS_COUNCI
# SLOPE_FAILURE
# THE_PROMISE_GROUP
# RIVERVIEW_MANOR
# JEWISH_FAMILY_AND_CHILDRENS_SE
# FRIENDSHIP_COMMUNITY_GROUP
# EAST_CARSON_STREET_(PENNDOT)
# PUBLIC_SAFETY_CAMERAS
# DEMOLITION_OF_CONDEMNED_BLDG
# POINT_PARK_UNIVERSITY_PLAY_HOU
# ASSOCIATED_MASTER_PLUMBERS_OF
# SPRING_HILL_CIVIC_LEAGUE_CC
# NEIGHBORHOOD_BUSI_ECON_DEVELOP
# MAJOR_DEVELOPMENT
# JEWISH_FAMILY_AND_CHILDRENS_S
# ROX_PERFORMANCE_ACADEMY
# CARRICK_COMMUNITY_COUNCIL_COM
# DISABLED_AND_PUB_SIDEWALK_EC
# JONCAIRE_STEPS_PENNDOT
# DOT_MON_WHARF
# DISTRICT_4_NEIGHBORHOOD_NEEDS
# POOL_EQUIPMENT_UPGRADES
# MC_FARREN_ST9_MILE_RUN_BRIDGE
# LOCAL_AUTOMATED_RED_LIGHT_ENFO
# AFRO_AMERICAN_MUSIC_INSTITUTE
# THE_OPEN_DOOR
# ARC
# URA_PERSONNEL_ECONOMIC_DEVELOP
# URA_PERSONNEL_HOUSING
# DISTRICT_1_WALLS,_STEPS,_FENCE
# PITTSBURGH_MUSICAL_THEATER
# BLOOMFIELD_PRESRV_AND_HERITAGE
# BLOOMFIELD_CITIZENS_COUNCIL
# JUSTICE_ASSISTANCE_GRANT
# PENNDOT_LOCAL_SHARE
# LIBERTY_AVENUE_SINC_UP
# MT_WASHINGTON_SIDEWALK_RECONST
# WORKFORCE_DEVELOPMENT_FUND
# PERSONNEL_CP
# EQUAL_OPP_REVIEW_COMMISION
# FINANCE_TAX_COLLECTION_AND_COM
# FINANCE_BPFAS
# REC_AND_SENIOR_CENTER_REHAB
# STORMWATER_MANAGEMENT_TRUST_FU
# PHMC_ARCH_INVENTORY
# PAHMC_2017_INVENTORY
# PERSONNEL_CITY_PLANNING
# PGH_PARTNERSHIP_EMPLOY_ADMIN
# MT_WASHINGTON_CDC
# HOUSING_AUTHY_REC_PROG_AND_SR
# COMPREHENSIVE_PLANS
# FRIENDSHIP_CIRCLE
# HIGHER_ACHIEVEMENT_INC
# MELLON_INNOVATION_ROADMAP
# ALTERNATIVE_FUELS_INCENTIVE_GR
# AFIG_ELECTRIC_VEHICLE_PROJECT
# AFIG_CHARGING_STATION
# HEINZ_LANGUAGE_GRANT
# TOWNSEND_PARKLET_DCNR_GRANT
# I_AND_P_SWITCHES
# HILLMAN_INNOVATION_ROADMAP
# STREET_RESURFACING
# MELWOOD_TRAFFIC_CALMING
# SENIOR_COMMUNITY_PROGRAM
# RESIDENTIAL_ACCESSIBILITY_IMPR
# RESIDENTIAL_FACADES_IMPROVED
# URBAN_REDEVELOPMENT_AUTHORITY
# NEWSUBSTANTIALLY_RENOVATED_FO
# SAFE_STREETS,_SMART_CITIES_AWA
# ZELLOUS_HOPE_PROJECT
# MT_WASHINGTON_HTS_ATHLETIC
# GYM_FLOOR_UPGRADES
# SHERADEN_UNITED_METHODIST_KIDZ
# NEIGHBORHOOD_LEARNING_ALLIANCE
# CULTURAL_HERITAGE_PLAN
# DRUG_ABUSE_RESISTANCE_ED_TF
# ENTERPRISE_RESOURCE_PLANNING
# NATURALLY_NORTHSIDE
# PPCBUHL_NATURALLY_NORTHSIDE_2
# GREENFIELD_AVE_STEP_UPGRADES
# HOMEWOOD_SIGN_REIMBURSEMENT
# PIRATES_CAHRITIES_CITISPORTS_Y
# EMERGENCY_SHELTER
# EMERGENCY_SHELTERING
# LIBERTY_AVE_SIGNAL_REIMBURSEME
# CENTER_FOR_INNOVATION_AND_ENTR
# DISTRICT_2_NEIGHBORHOOD_NEEDS
# FIRE_EQUIPMENT_2019
# LANDFORCE
# GARFIELD_JUBILEE_ASSOCIATION
# BIG_BROTHERS_BIG_SISTERS_OF_GR
# CITIZEN_PARTICIPATION
# LINCOLN_PLACE_PRESBYTERIAN
# COMMUNITY_FOOD_BANK
# CITIES_OF_TOMORROW_CHALLENGE
# LIFESPAN,_INC
# CHILDRENS_MUSEUM_OF_PITTSBURG
# HILL_COMMUNITY_DEVELOPMENT_COR
# BROWNSFIELD_ECONOMIC_DEVELOPME
# SUE_MURRAY_PLAYGROUND_IMPROVEM
# AFRICAN_AMERICAN_CHAMBER_OF_CO
# URBAN_LEAGUE_HOUSING_COUNSELIN
# RECONSTRUCTION_OF_FORBES_AVE
# ELIZABETH_PARK_ART_PROJECT
# MACEDONIA_FAMILY_AND_COMMUNITY_E
# MACEDONIA_FACE
# COMPUTER_REACH
# SOUTHSIDE_SLOPES_NEIGHBORHOOD
# YMCA_OF_GREATER_PITTSBURGH
# YMCA_OF_GREATER_PITTSBURGH_HOM
# PENNSYLVANIA_RESOURCES_COUNCIL
# SAINT_PAULS_BENEVOLENT_AND_MISS
# BRIGHTWOOD_CIVIC_GROUP_HOUSING
# PITTSBURGH_MEDIATION_CENTER
# NFL_FOUNDATION
# UPTOWN_PLANNING_STUDY
# TRID_GRANT_URA
# WESTERN_PA_ATHLETIC_LEAGUE
# SHEPHERD_WELLNESS_COMMUNITY
# LITTLE_SISTERS_OF_THE_POOR
# SHEPARD_WELLNESS_CENTER
# OPEB_TRUST_POLICE
# WESTERN_PENNSYLVANIA_CONSERVAN
# BRASHEAR_ASSOCIATION
# BRASHEAR_ASSOC
# ALLEGHENY_CITY_CENTRAL_ASSOCIA
# PITTSBURGH_PARKS_CONSERVANCY
# BRASHEAR_ASSOC_HENRY_KAUF
# LINCOLNPLACE_PRESBYTERIAN_CHUR
# BLOOMFIELD_GARFIELD_CORP
# CENTER_VICT_OF_VIOL_CRIME_MO
# PGH_ACTION_AGAINST_RAPE
# MANCHESTER_CITIZENS_CORPORATIO
# NATL_COUNCIL_OF_JEWISH_WOMEN
# NATIONAL_COUNCIL_ON_JEWISH_WOM
# CONSTRUCTION_MANAGEMENTINSPEC
# PROJECT_MANAGEMENT_SERVICES
# PARK_RANGER_GRANT
# PITTSBURGH_TRADE_INSTITUTE
# COMMUNITY_ALLIANCE_FOR_SPRING
# EAST_ALLEGHENY_COMMUNITY_COUNC
# JEWISH_COMMUNITY_CENTER
# JEWISH_COMMUNITY_CENTER_YOUNG
# ST_MARKS_EVANGELICAL_LUTHERAN
# SMALLMAN_STREET_URA
# ENERGY_INNOVATION_CENTER
# PUBLIC_SCHOOL_DESIGN_STUDY
# SCHOOL_DESIGN_STUDY
# PITTSBURGH_GREENWAYS_DCNR
# PIRATES_CHARITIES_FOR_DEVLIN_F
# PIRATES_CHARITIES_FOR_DINAN_FI
# CITY_ENERGY_PROJECT
# SPLASH_ZONES_PAYGO
# BUILDING_MAINTENANCE_PROGRAM
# 2015_JUSTICE_ASSISTANCE_GRANT
# BROOKLINE_CHRISTIAN_FOOD_PANTR
# PITTSBURGH_COMMUNITY_KITCHEN
# DISTRICT_8_NEIGHBORHOOD_NEEDS
# RECON_FORBES_AVE,_PHASE_1B
# BUILDING_COMMUNITY_TRUST_AND_J
# UPTOWN_PARTNERS
# SLOPE_FAILURE_REMIDIATION
# SLB_RADIO_PRODUCTIONS
# POOL_LINER_UPGRADE_MCBRIDE_POO
# LITTER_CAN_UPGRADES_AND_MONITO
# 75_NEW_LITTER_CANS
# LANDER_ST_SLOPE_IMPROVEMENTS
# TREE_OF_HOPE
# CHILDREN_2_CHAMPIONS
# TREE_OF_HOPE,_INC
# ARTISTIC_BANNER_PROJECT
# SWIMMING_POOL_REHABILITATION
# ENTERPRISE_RESOURCE_PLANNING_S
# SCHENLEY_HEIGHTS_CDC
# LAWRENCEVILLE_CORPORATION
# BLOOMFIELD_DEVELOPMENT_CORPORA
# CENTER_VICTIM_VIOLENT_CRIME_C
# PENN_AVENUE_RECONSTRUCTION
# JEFFERSON_PLAYGROUND_SITEACCE
# JEWISH_ASSOCIATION_ON_AGING
# AUDIBLE_TRAFFIC_SIGNALS
# BOB_OCONNOR_GOLF_COURSE
# ROSEDALE_BLOCK_CLUSTER
# RESERVE_FOR_2019_BOND
# OPERATION_WEED_AND_SEED
# USDEOT_TIGER_II
# EMMAUS_COMMUNITY_OF_PITTSBURGH
# CDBG_ADMINISTRATIVE_COSTS
# DISTRICT_3_NEIGHBORHOOD_NEEDS
# ANDERSON_STREET_UNDERPASS
# BRIDGE_INSPECTION_PROGRAM
# READING_IS_FUNDAMENTAL_PITTSBU
# OAKLAND_PLANNING_AND_DEV_CORP
# BUILDING_BRIDGES_FOR_BUSINESSE
# TO_CATHOLIC_CHARITIES
# BIRMINGHAM_FOUNDATIONMT_WASHI
# MON_WHARF_RIVERLIFE
# HOPE_FOR_TOMORROW
# OAKLAND_BUSINESS_IMPROVEMENT_D
# HAZELWOOD_MASTER_PLAN
# WESTERN_PENNSYLVANIA_SCHOOL_FO
# DEMOLITION_OF_CONDEMNED_BUILDI
# CREEDMOOR_COURT
# BAKERY_SQUARE_CONSENT_DE_DOMI
# NATIONAL_REGISTRY_FOR_LAWRENCE
# FACILITIES_TRUST_FUND
# REC_AND_SEN_CENTER_MAINT
# WAYFINDERS_SIGNAGE_TF
# ENTERPRISE_RESOURCE_CONSULTANT
# FINANCIAL_EMPOWERMENT_CENTERS
# PERSONNEL_URA
# MAINTENANCE_AND_ENHANCE_RECS
# NEIGHBORHOOD_ECONOMIC_DEVELOP
# PORT_SECURITY_GRANT
# PAHMC_ARCHITECTURAL_INVENTORY
# DCNR_MON_WHARF_SWITCHBACK
# DCNR_PAULSON_PARK
# SCHENLEY_PARK_TRAFFIC_SIGNAL
# 420_BOULEVARD_OF_THE_ALLIES
# TRAINING_CENTER_DESIGN_STUDY
# HIGHLAND_AVE_STREETLIGHT_PROJE
# WALL,_STEP_AND_FENCE_PROGRAM
# ARCHITECTURAL_ENGINEERING_SERV
# LIVING_CITIES_STEPS_ASSESSMENT
# PACE
# LARIMER_GREEN_TEAM
# HARTFORD_FIRE_PREVENTION
# ACCOMANDO_COMMUNITY_CENTER
# ECONOMIC_DEVELOPMENT_SOUTH
# CARRICKCOMMUNITY_COUNCIL_COMP
# CARRICK_COMMUNITY_COUNCIL
# SHERADEN_UNITED_METHODIST_CHUR
# OLYMPIA_PARK_DOG_PARK
# STEEL_CITY_BOXING
# RESILIENCE_AMERICORPS
# RECREATION_AND_SENIOR_CENTER_MAI
# ERP_CONSULTANT
# RESERVE_FOR_2018_BOND_ISSUE
# WEST_END_BALLFIELDS
# MANCHESTER_FIELD
# CITY_CLERKS_NEIGHBORHOOD_NEEDS
# NORTH_SIDE_LEADERSHIP_COUNCIL
# DHSFEMA_PORT_SECURITY_GRANT
# PEOPLES_GAS_2017_LYB
# CITY_OF_ASYLUM
# ST_AMBROSE_MANOR
# FOWLER_FIELD
# KENNARD_FIELD
# ROCKEFELLER_100RC
# HEINZ_MULTICULTURAL_LIASON
# PENN_AVENUE,_PHASE_1
# NEIGHBORHOOD_STREET_IMPROVEMEN
# PENN_AVENUE_PHASE_I
# JAG
# PITTSBURGH_AIDS_TASK_FORCE
# ARLINGTON_FOOD_BANK
# CATHOLIC_CHARITIES,_DIOCESE_OF
# DEUTSCHTOWN,_EAST_OHIO_STREET
# VIETNAM_VET_LEADERSHIP_PROGRAM
# CRIMINAL_INTELLIGENCE
# ERP_SYSTEM
# DCED_FIFTHTHIRD_CORRIDOR
# HILL_HOUSE
# HILL_HOUSE_ASSOCIATION
# LAWRENCEVILLE_CORP
# 2016_ASSISTANCE_TO_FIREFIGHTER
# PREVENT_ANOTHER_CRIME_TODAY
# NORTHSIDE_CHRONICLE
# DISABLED_AND_PUBLIC_SIDEWALK_PRO
# TROY_HILL_CITIZENS_COUNCIL
# FINEVIEW_CITIZENS_COUNCIL,_INC
# EAST_ALLEGHENY_COMM_COUNCIL
# INFORMATION_SYSTEMS_MODERNIZAT
# LOWER_BLOOMFIELD_UNITY_COUNCIL
# BEECHVIEW_MERCHANTS_ASSOC
# AMANI_CHRISTIAN_DEVELOPMENT_CO
# BALLFIELD_LIGHTING
# STATE_EMERGENCY_SOLUTIO_2015
# DCED_MON_WHARF
# TRINITY_LUTHERAN_CHURCH
# BEECHVIEW_COMMUNITY_AND_SENIOR
# CARRICK_DAIRY_DISTRICT_STREETS
# FINANCIAL_INCLUSION
# PW_ENGINEERING_AND_CONSTRUCTIO
# WALMART_FOUNDATION_ZONE_5
# 2ND_AVE_BRDG_OVER_9_MILE_RUN
# OPEB_TRUST_FIRE
# PHIPPS_CONSERVATORY
# NEIGHBORHOOD_HOUSING_INITIATIV
# BUILDING_MAINTENCE_PROG
# COMMUNITY_EMPOWERMENT_ASSOCIAT
# SUMMER_YOUTH_EMPOLYMENT
# ST_CLAIR_ATHLETIC_ASSOCIATION
# JEWISH_FAMILY_REFUGEE_SERVIC
# POLISH_HILL_CIVIC_ASSOCIATION
# ST_MICHAELS_FOOD_BANK
# SUMMER_YOUTH_EMPLOYMENT_PROG
# EMS_EQUIPMENT
# SAINT_ROSALIA_FOOD_BANK
# STREET_RESURFACING_PAYGO
# AUTO_THEFT_TF_II
# BROOKLINE_BLVD
# HIGHMARK_SUMMER_YOU_2015
# HEINZ_PERMITTING
# ARCHITECTURAL_INVENTORY
# RESERVE_FOR_CO_40011
# RESERVE_FOR_2012_BOND_ISSUE
# EXPENDITURE_BU_FOR_CAFR
# HIGHWAY_SAFETY_GRANT_PENNDOT
# W_PA_POLICE_ATHLETIC_LEAGUE
# HABITAT_FOR_HUMANITY_HOME_RE
# WOODS_RUN_CARNEGIE_LIBRARY
# NEIGHBORHOOD_STREET_IMPROV
# STRONG_WOMEN,_STRONG_GIRLS
# BUILDING_IMPROVEMENTS_PLAN
# DCNR_EMERALD_VIEW_PARK_GRANT
# CITYWIDE_STREET_LIGHTS
# PANGIS_TRUST_FUND
# VENDING_TF_CONTROLLER
# URBAN_KIND_INSTITUTE
# BICYCLE_AND_TRANSPORTATION_PLA
# YMCA_CENTRE_AVE
# BLLOMFIELD_GARFIELD_CORPORATIO
# BEYOND_TRAFFIC:THE_SMART_CITY
# SIGNAGE_AND_WAYFINDING
# OBSERVATORY_HILL,_PERRYSVILLE
# PUBLIC_SAFETY_RADIO_REPLACEMEN
# HEINZ_LED_ASTRONOMICAL_FOOTPRI
# IN_CAR_CAMERA_SYSTEM
# PENN_AVE_DESIGN
# TROY_HILL,_LOWRIE_STREET,_BUSI
# COMMUNITY_ALLIANCESPRING_GARD
# SARAH_HEINZ_HOUSE
# ETHICS_BOARD_TRUST_FUND
# USDOJ_BODY_WORN_CAMERA_GRANT
# PROJECT_MANAGEMENT_AND_ADMINIS
# LEAD_SAFE_FOR_KIDS_SAKE_AWARD
# PENN_AVE_RECONSTRUCTION
# CENTRAL_BAPTIST_CHURCH
# MARION_MANOR
# PHILLIPS_PARK_IMPROVEMENTS
# TAX_REFUNDS_CITY
# YMCA_HAZELWOOD_BRANCH
# YMCA_HAZELWOOD
# YMCA_HOMEWOOD
# ST_JOHN_VIANNEY_PARRISH
# PENNSYLVANIA_CONNECTING_COMMUN
# NLC_NS_ROX_YOUTH_MUSIC
# URBAN_LEAGUE_HUNGER_SERVICES
# ATPA_AUTO_THEFT_PREVENTION
# POLICE_MOUNTED_UNITS
# NLC_WEST_COMMONS_TENNET_COUNCI
# DISTRICT_6_NEIGHBORHOOD_NEEDS
# DOJ_JUSTICE_ASSISTANCE_2014
# DPW_POOL_REHABILITATION
# POOL_REHABILITATION_EC
# FEDERAL_CARRIER_GRANT
# DISTRICT_9_NEIGHBORHOOD_NEEDS
# CITY_CLERKS_OFFICE_MODERNIZE
# PA_HISTORICAL_MUSEUMS
# LINCOLN_PLACE_REC_CENTER
# LINCOLN_PLACE_PARK_RENOVATION
# MON_WHARF_URA
# 2ND_AVENUE_AND_MCFARREN_BRIDGE
# WOODLAND_SHADELAND_HOUSING
# WOODLANDSHADELAND_HOUSING_INI
# JEWISH_FAMILY_CAREER_DEVELOP
# PRESERVE_PGH_NATIONAL_REGISTRY
# PGH_COM_REINVESTMENT_GROUP
# SOUTH_SIDE_COMMUNITY_COUNCIL
# MENTORING_PARTNERSHIP_VISTA_PR
# REBUILDING_TOGETHER_AMERICORPS
# BIG_BROTHERS_BIG_SISTERS
# LYNN_WILLIAMS_HIGH_RISE
# BRASHEAR_ASSOC_HENRY_KAUFMAN
# KABOOM_DCNR
# CENTER_FOR_LIFE
# BEECHVIEW_SENIOR_AND_COMMUNITY
# LAWRENCEVILLE_TECHNOLOGY_GRANT
# HILL_DISTRICT_CONSENSUS_GROUP
# ALLEGHENY_CLEANWAYS
# HOMEWOOD_CONCERNED_CITIZENS_CO
# CATHOLIC_YOUTH_ASSOC_LAWRENCEV
# IMPAIRED_DRIVER_GRANT_PA_DOT
# ELLIOTT_WEST_END_ATHLETIC
# PENNSYLVANIA_WOMEN_WORK
# RESERVE_FOR_2017_BOND_ISSUE
# FIREFIGHTING_EQUIPMENT
# FIRE_FIGHTING_EQUIPMENT
# FIRE_EQUIPMENT
# INNOVATION_FELLOW
# DISTRICT_7_NEIGHBORHOOD_NEEDS
# EMERGENCY_SHELTER_2015
# POLICE_FACILITIES_UPGRADE
# LOCAL_LAW_ENFORCEMENT
# RCAP_BEECHVIEW_SENIOR_CENTER
# POLICE_EQUIPMENT
# PGH_ACTION_AGAINST_RAPE_CC
# BRIGHTON_HRIGHTS_SENIOR_CENTER
# RIVERVIEW_TOWER_APARTMENTS
# NLC_SHEPETSKY_ARMS
# PITTSBURGH_SOCCER_IN_THE_COMMU
# SOUTHSIDE_SLOPES_REPAIRS
# KING_MELLON_ARTWRK_CONSERVATIO
# HILLMAN_CITY_ID
# ARCHITECTURAL_SURVEY_GIS
# CITY_CLERKS_OFFICE_MODERNIZATI
# SCHENLEY_PARK_WESTINGHOUSE_MEM
# LARIMER_GREEN
# MT_WASHINGTON_CDC_QUALITY_OF_L
# PEOPLES_GAS_2015_LYB
# MT_WASHINGTON_COMM_DEV_CORP
# BLOOMFIELD_CITIZEN_COUNCIL
# ST_ANDREWS_LUTHERAN_CHURCH
# HILLTOP_ALLIANCE_ALLENTOWN_CDC
# WOOD_STREET_PUBLIC_SPACE_IMPRO
# TIP_REVOLVING_FUND_2014
# SHERADEN_COMMUNITY_COUNCIL
# LINDEN_SCHOOL_PTO
# CENTER_VICTIM_VIOLENT_CRIME_CC
# GRANDVIEW_LIONS_CLUB
# TRAIL_REPAIRS
# 2013_PGH_SUMMER_YOUTH_EMPLOYME
# HEINZ_LEAN_SIGME_6
# EMERALD_ASHE_BORER
# NEIGHBORHOOD_WORKS_OF_WESTERN
# ALEPH_INSTITUTE
# LIFES_WORK_OF_WESTERN_PABEN
# REFINISH_GYMNASIUM_FLOOR
# YOUNG_MEN_AND_WOMENS_HEBREW
# FIREFIGHTING_PROTECTIVE_CLOTH
# PS_BBI
# BRASHEAR_ASSOCIATION_ARLINGTON
# BRASHEAR_ASSOCHENRY_KAUFMAN
# LUMA_TRAINING_HEINZ
# HIGHWAY_SAFETY_TF
# COMMUNITY_BASED_ORGANIZATION
# NORTHSIDE_LEADERSHIP_CONHISTO
# SWIMMING_POOL_MAINTENANCE
# HEINZ_POLICE_TRAINING_GRANT
# SINC_UP_TRAFFIC_SIGNAL_IMPROVE
# EORC_SOFTWARE
# RECONSTRUCTION_OF_FROBES_AVE
# HDR_FOR_GREENFIELD_AVE_BRIDGE
# PARK_WATER_FOUNTAINS
# REC_AND_SENIOR_CENTER_MAINTENANC
# MAINTENANCE_AND_ENHANCE_REC_S
# SPRINGHILL_SPRING_RESTORATION
# SOUTH_HIGHLAND_AVENUE_BRIDGE
# RENTAL_PERMIT_TF
# BIKE_SHARE_PROGRAM
# PITTSBURGH_BIKE_SHARE
# SOUTH_SIDE_ATHLETIC_ASSOCIATIO
# NORTHSIDE_OLD_TIMERS
# ARTS_FOR_AUTISM_FOUNDATION_OF
# ALLIES_FOR_CHILDREN_AMERICORPS
# BUTTONWOOD_STREET_LOW_VOLUME_R
# NATIONAL_LEAGUE_OF_CITIES
# OPEN_SPACE_TRUST_FUND
# SPRINGHILL_SPRING
# MT_WASHINGTON_CDC_BEECHVIEW
# DEPAUL_ACHOOL_FOR_HEARING_AND
# DEPAUL_SCHOOL_FOR_HEARING_AND
# CONSTRUCTION_DIVISION
# LOWER_HETHS_RUN_ATHLETIC_FIEL
# MY_BROTHERS_KEEPER
# FEMA_RADIOS
# EMERGENCY_SHELTER_2014
# NORTHSIDE_PUBLIC_SAFETY_COUNCI
# ECONOMIC_DEVELOPMENT_AND_DESIG
# MANCHESTER_CITIZENS_CORP
# MULTI_MODAL_TRANSPORTATION_PLA
# PRIME_STAGE_THEATRE
# FEMA_FIREFIGHTERS_TRAINING
# FIREFIGHTING_PROTECTIVE_CLOTHI
# OAK_WILT_GRANT
# PMA_BODY_ARMOUR_AND_BODY_CAMER
# NORTHSIDE_COALITION_FOR_FAIR_H
# TAX_REFUNDS_SCHOOL
# WALL,_STEP,_AND_FENCE_EC
# JEWISH_COMM_CENTER
# BIKE_SHARE_PROGRAM_FOR_PROFIT
# WALL,_STEP_AND_FENCE_PAYGO
# BETHLEHEM_HAVEN
# SQUIRREL_HILL_HEALTH_CENTER
# PROPERTY_MANAGEMENT
# BELTZHOOVER_CIVIC_ASSOCIATION
# ARCHENGINEER_SERVICES
# PCCD_PROJECT_SAFE_NEIGHBORHOOD
# WEST_END_ALLIANCE_COMMUNITY_DE
# FINEVIEW_HOUSING
# PHMC_ARCH_PLANNING_GRANT
# LOVE_YOUR_BLOCK_PROGRAM
# PGH_FOUNDATION_NEIGHBORHOOD_EM
# HILLMAN_FOUNDATION_NEIGHBORHOO
# HEINZ_BNE_SUPPORT
# PROVIDENCE_CONNECTIONSMEETIN
# HEALTHY_START
# TREE_MAINTENANCE_PROGRAM
# MCARDLE_ROADWAY
# FIELD_AUTOMATION_INITIATIVE
# DISTRICT_1_DEMOLITION
# 2015_SUMMER_YOUTH_PGH_FOUNDATI
# HEINZ_PUBLIC_ART
# RECONSTRUCTION_OF_FORBES_AVENU
# LEOLYN_PARKLET_IMPROVEMENT
# HOMEWOOD_CAMERAS
# MCKINLEY_PARK_TRACK
# ECONOMIC_SURVEY:PRESERVATION
# BLOOMFIELD_RECREATION_CENTER
# BLOOMFIELD_DECK_HOCKEY
# ELECTRONIC_DAILY_ACTIVITY_SHEE
# FINANCIAL_LITERACY_PROGRAM
# BUHL_FOUNDATION_NEIGHBORHOOD_E
# HIGHWAY_SAFETY_PROGRAM
# PA_HMC
# BEECHWOOD_BLVDBROWNSHILL_RD
# SOUTH_HIGHLAND_AVE_BRIDGE
# SQUIRREL_HILL_BUSINESS_DISTRIC
# TRAFFIC_IMPROVEMENTS
# YMCA_OF_GREATER_PGH_HAZELWOOD
# LAWRENCEVILLE_CORP_PARKING_SOL
# WEB_BASED_PERMITTING_PROJECT
# EAST_LIBERTY_INFRASTRUCTURE
# NRPA_COMMUNITY_GARDENS_GRANT
# RECREATION_CENTER_WIFI_GRANT
# AMERICAN_DISABILITY_ACT
# PUBLIC_SAFETY_SYSTEMS
# DISTRICT_5_NEIGHBORHOOD_NEEDS
# NORTHSIDE_COALITION_FAIR_HOUSI
# HEINZ_PEDESTRIAN_BIKE_PATH
# PRIME_STAGE_THEATER
# GARFIELD_YOUTH_SPORTS_CO_BLOO
# CHILDRENS_SICKLE_CELL_FOUNDAT
# EASTSIDE_NEIGHBORHOOD_EMPLOYME
# CHILDRENS_MUSEUM
# AMANI_CHRISTIAN_COMMUNITY_DEVE
# WENZELL_AVENUE_RECONSTRUCTION
# PUBLIC_SAFETY_RADIOS
# CITY_COUNCIL_CHAMBERS
# WENZELL_AVE_RECONSTRUCTION
# ALLENTOWN_COMMUNITY_DEVELOPMEN
# STEELWORKERS_TOWER
# CENTER_THAT_CARES
# OAKLAND_COMMUNITY_HEALTH_SERVI
# JERON_X_GRAYSON_CENTER
# BEECHVIEW_MANOR
# YOUTH_PLACESREAM_RECREATION_C
# DEPAUL_SCHOOL
# RADIO_SYSTEM_UPGRADE(DPW)
# CODE_FOR_AMERICA
# AUTOMATED_FUEL_DISPENSING_SYST
# EMERGENCY_SHELTER_2013
# HAZELWOOD_MAINT_TASK_FORCE
# MINORITY_AND_WOMEN_EDUCATIONAL
# MINORITY_WOMEN_EDUCATIONAL_LAB
# CATHOLIC_YOUTH_ASSOCBLOOMFIEL
# PITTSBURGH_STRUGGLING_STUDENTS
# WELCOMING_PITTSBURGH_INITIATIV
# DCED_ENERGY_AND_UTILITIES
# MCARDLE_ROADWAY_VIADUCT_#1
# NORTHSIDE_FAIR_HOUSING_COALITI
# EAST_LIBERTY_HOUSING,_INC
# GWENS_GIRLS
# DRESS_FOR_SUCCESS
# STIMULUS_BYRNE_JUSTINCE_ASSIST
# PLISH_HILL_CIVIC_ASSOCIATION
# PARKS_CONSERVANCY_ARSENAL_PARK
# UJAMAA_COLLECTIVE
# AMANI_CHRISTION_COMMUNITY_DEVE
# FINEVIEW_CITIZENS_COUNCIL_CC
# FORBES_AVE_AND_MARKET_STREET
# DHHS_EARLY_RETIREMENT_GRANT
# TRAFFIC_SIGNAL_HARDWARE
# COMMUNITY_BASED_ORG_CP
# RIVERVIEW_COMMUNITYSENIOR_CEN
# YOUTH_PLACES_HURRICANES_YOUT
# CENTRAL_NORTHSIDE_NEIGHBORHOOD
# BROWNS_HILL_ROAD
# YOUTH_PLACES_REAM
# PEMA_FIRE_EQUIPMENT_GRANT
# WIRELESS_NEIGHBORHOODS
# TOMORROWS_FUTURE
# DISTRICT_1_EQUIPMENT
# NEIGHBHD_ECONOMIC_DEVELOPMENT
# HISTORIC_DEUTSCHTOWN_DEV_CORP
# URBAN_LEAGUE_HUNGER_SERVICES_N
# MCARDLE_VIADUCT_#1_CONSTRUCTIO
# DOG_PARKS
# NEIGHBORHOOD_BUSINESS_AND_ECON
# PORTMAN_SLOPE
# FIREFIGHTING_GRANT_MATCHING_FU
# YOUNG_MEN_AND_WOMENS_AFRICAN
# SHOTSPOTTER_PROGRAM
# MASTER_PLAN_31ST_WARD
# WILKSBORO_BRIDGE
# PHILLIPS_PARK_IMPROVEMENT
# OAKWOOD_WALKING_TRAIL
# CARRICK_NEIGHBORHOOD_IMPROVEME
# WENZELL_AVENUE
# PARK_CONSERVANCY_ARSENAL_PARK
# SAINT_MARKS_EVANGELICAL_LUTHE
# TRI_HILL_VALLEY_MEALS_ON_WHEEL
# TRI_VALLEY_MEALS_ON_WHEELS
# THE_WHEEL_MILL
# YMCA_OF_GREATER_PGH_CENTRE_AVE
# LINCOLN_PLACE_RECREATION_CNTR
# HIGHMARK_SUMMER_YOUTH_PROGRAM
# STATE_EMERGENCY_SOLUTIO_2011
# RESPONSIBLE_HOSPITALITY
# GREEN_UP_PITTSBURGH_DCED_URA
# PROPERTY_MANAGEMENT_AND_RELOCATI
# USDOT_FEDERAL_MOTOR_CARRIER_PR
# PENNDOT_STRIP_DISTRICT_LAND
# NORTHSIDE_LEADERSHIP_CONFERENC
# SALVATION_ARMY
# INFORMATION_SYSTEMS_MODERN
# BEECHVIEW_RENOVATION
# NEGLEY_AVENUE
# WALL_STEP_AND_FENCE_PROGRAM
# WALL,_STEP_AND_FENCE_EC
# OPERATION_BETTER_BLOCK
# EMERGENCY_SHELTER_2011
# BELTZHOOVER_NBH_COUNCIL
# RECREATION_GRANTS_MATCHING_FUN
# DCNR_TREE_VITALIZE
# SPAY_AND_NEUTER_PROGRAM
# ELEVATOR_REPAIR_AND_MAINTENANCE
# MT_WASHINGTON_COMMUNITY_DEVELO
# BRIGHTWOOD_BUSINESS_DISTRICT
# PROPERTY_MANAGEMENT_AND_RELOCA
# COMMUNITY_DESIGN_CENTER_OF_PIT
# COMMUNITY_DESIGN_CENTER
# PENN_WORKS_LTV_HAZELWOOD
# THE_POISE_FOUNDATION
# ELDER_ADO
# MARILYN_G_RABB_FOUNDATION
# MT_WASHINGTON_CDC_SHILOH_ST
# TRAIL_AND_BIKE_ROUTE_DEVELOPMENT
# LAWRENCEVILLE_BLOOMFIELD_MEALS
# BRIGHTON_HEIGHTS,_CALIFORNIA_A
# BRIGHTON_HEIGHTS_MEALS_ON_WHEE
# COLCOM_FOUND_PRO_WALKBIKE
# RK_MELLON_FOUND_PRO_WALKBIKE
# AUGUST_WILSON_HOME_PROJECT
# HOME_DEPOT_LOVE_YOUR_BLOCK_GRA
# NEIGHBORHOOD_STABILIZATION_PRO
# ZONE_3_POLICE_STATION_RELOCATI
# TWO_LIFT_SYSTEMS_AND_POWER_COTS
# MANCHESTER_ELEMENTARY_PTA
# HEINZ_URBAN_DESIGN
# NORTH_SIDE_COMMUNITY_DEVELOPME
# ELDER_ADO_INC
# CITY_COUNTY_BUILDING
# BRIGHTWOOD_ATHLETIC_ORG
# ACCULT_FOR_JUSTICE,_ACCESS,_P
# HILL_DISTRICT_CDC
# PITTSBURGH_COMMUNITY_SERVICES_
# EMERGENCY_SHELTER_2012
# BROAD_STREET
# EAST_LIBERTY_DEVELOPMENT
# COMMUNITY_EMPOWERMENT
# WESTERN_PA_ATHLETIC_ASSOCIATIO
# STREET_LIGHTING
# MAYORS_OFFICE_NEIGHBORHOOD_NE
# BEECHVIEW_SENIOR_CENTER
# DOJ_COPS_TECH_GRANT_2
# MCARDLE_VIADUCT_#1
# MANCHESTER_YOUTH_DEVELOPMENT
# RENEWAL,_INC
# ARCHITECTURAL_ENG_SERV
# SWIFT_WATER_RESCUE
# COMMUNITY_TECHNICAL_ASSISTANCE
# NEIGHBORHOOD_ECONOMIC_DEVELOPM
# NEIGHBORS_IN_THE_STRIP
# COLCOM_FOUNDATION_DEV_OF_A_COM
# ISAIAH_PROJECT
# CITIES_OF_SERVICE_2
# BROOKLINE_MEALS_ON_WHEELS
# BLOOMFIELD_GARFIELD_CORP_COMMU
# FACILITIES_MAINTENENCE_PROGRAM
# CONCRETE,_BRICK,_AND_BLOCK_STO
# NEIGHBORHOOD_LEGAL_SERVICES
# WARRINGTON_AVENUE_RECONSTRUCTI
# 2012_SUMMER_YOUTH_HIGHMARK
# WESLEY_AME_CHARITIES
# MELLON_PARK_RESTROOM_FACILITY
# SOLAR_AMERICAS_CITIES_GRANT
# 31ST_WARD_COMMUNITY_ACT_GRP
# YMCA
# YMCA_HOMEWOOD_BRANCH
# YOUTH_PLACES
# PA_HISTORICAL_AND_MUSEUM_SOCIE
# BOYS_AND_GIRLS_CLUB
# BROOKLINE_BOULEVARD
# MOVING_LIVES_OF_KIDS_ARTS_CENT
# HOMEWOOD_COMMUNITY_SPORTS
# POLICE_STATION_SECURITY_CAMERA
# POLICE_ZONE_ENTRANCE_RENOVATIO
# FIRE_HOSE_AND_SCBA_PARTS
# CAMERAPORT_SECURITY_PROJECT
# COPS_TECHNOLOGY_PROGRAM_DOJ
# YMCA_CENTER_AVE_BRANCH
# LIVING_MINISTRY
# LEGACY_ARTS_PROJECT
# SURVEY_GRANT_URA
# JEWISH_ASSOC_ON_AGING_MOLLIES
# PA_BEVERAGE_ASSOCIATION
# NORTHSIDE_STALLIONS
# MOTOR_CARRIER_SAFETY_2011
# ARCHENGINEERING_SERVICES
# REFORMED_PRESBYTERIAN_HOME
# ACTION_HOUSING
# EDUCATING_TEENS_ABOUT_HIVAIDS
# BEECHWOOD_BLVD
# CONSUMER_HEALTH_COALITION
# WAR_MEMORIALS
# OPEB_TRUST_FUND
# SWIMMING_POOL_MAINTENENCE
# CITY_OF_PITTSBURGH_RADIO_REPLA
# IMPAIRED_MOTORCYCLE_EDUCATION
# EECBG_STIMULUS_DOE
# HILLTOP_COMM_CHILDRENS_CTR
# RIVER_RESCUE_HOMELAND_SECURITY
# FANCOURT_STREET_BRIDGE_(TIP)
# SHERADEN_UNITED_METHODIST_SUM
# SHERADEN_UNITED_METHODIST
# ARLINGTON_CIVIC_COUNCIL_MEALS
# URBAN_LEAGUE_COUNSELING_PROG
# KEYSTONE_DEVELOPMENT_CENTER
# GREENFIELD_GRANT
# NATIONAL_COUNCIL_FOR_URBAN_PEA
# PLF_AMACHI
# SOUTH_SIDE_SABERS_YOUTH_FOOTB
# SENIOR_FRIENDS
# PORT_SERCURITY_GRANT_2BOATHOU
# HOSPITALITY_ZONE_ECONOMIC_AND
# FEMA_FIRE_PREVENTION
# CITIES_OF_SERVICE
# RK_MELLON_FOUNDATION
# SUMMIT_SCHOOL,_INC
# SOUTHSIDE_ATHLETIC_ASSOC
# FAMILY_RESOURCE_CENTER
# FAMILY_RESOURCES
# A_FOR_THE_PEOPLE_TRAINING_INST
# EAST_END_RAIDERS_KINGSLEY_AS
# EAST_END_RAIDERS_KINGSLEY_ASSO
# ST_AMBROSE_MANOR_VAN
# JEWISH_RESIDENTIAL_SERVICES_LO
# 2012_SUMMER_YOUTH_PITTSBURGH_F
# EAST_LIBERTY_PENN_CIRCLE
# EAST_LIBERT_PENN_CIRCLE
# PGH_COMM_SERVICE_SAFETY
# DCED_SOLAR_ENERGY_PROGRAM
# FANCOURT_STREET_BRIDGE
# DOLLAR_ENERGY_FUND
# DOLLAR_ENERGY_FUND,_INC
# JEWISH_ASSOCIATION_ON_AGING_
# JEWISH_ASSOCIATION_ON_AGING_K
# JEWISH_ASSOCIATION_ON_AGING_S
# JEWISH_COMMUNITY_CENTER_SENIOR
# MINORITY_LABOR_EDUCATION
# URBAN_LEAGUE_HOUSING_COUNCIL
# PARK_RECONSTRUCTION_PROG
# CATHOLIC_CHARITIES_OF_PGH
# MATRESS_FACTORY
# WASHINGTON_HEIGHTS_ATHLETIC_A
# HAZELWOOD_MEALS_ON_WHEELS
# BIKE_INFRASTRUCTURES
# MIRYAMS
# CENTRAL_N_SIDE_NBH_COUNCIL
# COALITION_FOR_FAIR_HOUSING
# WALL,_STEP,_AND_FENCE_PROGRAM
# VETERANS_LEADERSHIP_PROGRAM
# PGH_COMM_REINVESTMENT_GROUP
# BUILDING_MAINTENANCE_PROG
# SPLASH_ZONS
# ST_ANDREWS_FOOD_BANK
# LIBERTY_AVENUE_GREEN_BIKE_LANE
# OAKLAND_COMMUNITY_COUNCIL
# NATURAL_GAS_REFUSE_TRUCKS
# CAPITAL_ACQUISITION
# FRIENDSHIP_DEVELOPMENT_ASSOC
# REFINISH_GYMNASIUM_FLOORS
# HIGHMARK_SUMMER_YOUTH
# CDBG_ADMINISTRATION_COSTS
# SOUTH_SIDE_LIBRARY_GRANT
# URBAN_LEAGUE_COUNCIL_PROG
# ARLINGTON_CIVIC_COUNCIL
# SMART_TRID_PLANNING_SOUTH_HILL
# WASHINGTON_HEIGHTS_ATH_ASSOC
# SIDS_ALLIANCE,_PGH_AFFILIATE
# WESTERN_PA_CONSERVANCY_MO
# PA_AFFILIATE_SIDS_ALLIANCE
# ELEVATOR_REPAIR_AND_MAINT
# TREE_PLANTING_PROGRAM_MAYORS
# CHILDRENS_HOME
# STEEL_VALLEY_AUTHORITY_CC
# BELTZHOOVER_NGH_COUNCIL
# PEDA_STREETLIGHT_CONVERSION
# ARLINGTON_MEALS_ON_WHEELS
# EMANUEL_CHRISTIAN_PRESCHOOL
# TRAIL_EXPANSION_MAYORS
# EAST_END_RAIDERS
# SMALL_SEEDS
# WOMENS_CENTER_AND_SHELTER_MO
# SCHENLEY_HEIGHTS_DEVELOPMENT_P
# BATES_STREETSECOND_AVE_INTERS
# HPRP
# OVERBROOK_TOD_DEVO_DESIGN_STUD
# OBSERVATORY_HILL,_INC
# OBSERVATORY_HILL
# NORTHVIEW_HEIGHTS_ESTATE_MANOR
# THOMAS_MERTON_CENTER_GARFIELD
# SWIMMING_POOL_MAINT_TF
# BIO_DIESEL_RETROFIT_ACHD
# FAMILY_LINKS
# PUBLIC_SPACE_UPGRADE_OAKLAND
# SAINT_AMBROSE_MANOR
# NORTH_SHORE_COMMUNITY_ALLIANCE
# ALLEGHENY_YMCA
# HILL_DIST_CONSENSUS_GRPCOMM
# MT_WASHINGTON_CDC_HOUSE_T
# TRAIL_AND_BIKE_DEVELOPMENT
# PENNSYLVANIA_RESOURCE_COUNCIL
# DCED_SECTOR_PLANNING
# BATES_STREET2ND_AVE
# ALLEGHENY_COMMONS_INITIATIVE
# DECENTRALIZATION_OF_BBI_EMPLOY
# PERRY_HILLTOP_CITIZENS_COUNCI
# OAKLAND_PLANNING_AND_DEVELOPMENT
# FREEDOM_UNLIMITED
# SOUTH_SIDE_DOG_PARK
# LAWRENCEVILLE_CORPRELOCATION
# IW_ABEL_PLACE
# SCBA_ASSIST_TO_FIREFIGHTERS
# EAST_CARNEGIE_COMMUNITY_COUNCI
# UNIVERSAL_ST_ACADEMY_COMMUNITY
# COPIER_MANAGEMENT_AND_POSTAGE_TF
# URBAN_LEAGUE
# URBAN_LEAGUE_HOUSING_COUNSELNG
# ST_MATTEWS_FOOD_BANK
# SOUTHSIDE_MARKET_HOUSE
# BLOOMFIELD_BUSINESS_ASSOC
# SOUTHSIDE_ATHLETIC_ASSOCIATION
# NEW_HOPE_FOR_NEIGHBORHOOD_RENE
# SOUTHSIDE_SABERS_YOUTH_FOOTBA
# ALLENTOWN_COMMUNITY_DEVELOP
# HEINZ_CASINO_MEETING_GRANT
# SOUTHSIDE_MARKET
# SCBA_EQUIPMENT
# HILL_DANCE_ACADEMY_THEATRE
# GREATER_PGH_FOOD_BANK
# FINEVIEW_CITIZEN_COUNCIL_HENDE
# EMERGENCY_SHELTER_2010
# AGAPE
# JEWISH_FAMILY_AND_CHILDRENS_CEN
# URBAN_LEAGUE_HUNGER
# DCED_BUSINESS_DISTRICT_IMPROV
# BALLFIELD_LIGHT_REPLACEMENT
# MCARDLE_VIADUCT_NO_1
# CONTROLLERS_FIN_MGMT_INFO_SYS
# NORTHSHORE_COMMUNITY_ALLIANCE
# LIFES_WORK_OF_WESTERN_PA
# THREE_RIVERS_HERTG_TRAIL
# EAST_LIBERTY_TRID_PLANNING
# DCED_CITY_BUSINESS_DISTRICT_IM
# USDOTMOTOR_SAFETY_2

# %%
column = 'department_name'
unique_values = df[column].unique()
print(f"\nUnique values in column '{column}':")
for i in unique_values:
    print(i)
# Out:
# Unique values in column 'department_name':
# Innovation and Performance
# Department of Finance
# Department of Public Safety - Police
# Department of Public Safety - Fire
# Department of Public Works - Operations
# Parks and Recreation
# City Council
# City Clerk
# Mayor's Office
# Human Relations Commission
# Controller's Office
# Department of Law
# Personnel/Civil Service
# Department of City Planning
# Permits Licenses and Inspection
# Department of Public Safety - Administration
# Office of Municipal Investigations
# Department of Public Safety - Animal Care and Control
# Department of Public Works - Administration
# Department of Public Works - Environmental Services
# Department of Public Works - Facilities
# Mobility and Infrastructure
# Public Works
# Office of Management and Budget
# Department of Public Safety - Emergency Medical Services
# Urban Redevelopment Authority Projects
# Equipment Leasing Authority
# Equal Opportunity Review Committee
# Finance, Procurement and Fleet
# Department of Public Works - Transportation and Engine
# Department of Public Safety - Building Inspection

# %%
column = 'fund_description'
unique_values = df[column].unique()
print(f"\nUnique values in column '{column}':")
for i in unique_values:
    print(i)
# Out:
# Unique values in column 'fund_description':
# General Fund
# Senior Citizens Program Trust Fund
# Equal Employment Opportunity Commission Trust Fund
# Grants Fund
# Police Secondary Employment Trust Fund
# Mellon Park Tennis Trust Fund
# Allegheny Regional Asset District Public Works
# Housing and Urban Development Fair Housing Program Trust Fund
# Special Summer Food Service Trust Fund
# Allegheny Regional Asset District Parks
# Job Training Partnership Act
# Tree Taxing Bodies
# Community Development Block Grant Fund
# Emergency Medical Services Reimbursement Events Trust Fund
# Three Taxing Bodies Escrow Trust Fund
# Debt Service Project Fund
# Confiscated Narcotics Proceeds
# Emergency Shelters Program Trust Fund
# Solid Waste Trust Fund
# Public Works Trust Fund
# Shade Tree Trust Fund
# 2020 Pay-As-You-Go
# Special Parks Program Great Race
# Workers Compensation Commutations
# Voluntary Employees Beneficiary Association Health Insurance
# Voluntary Employees Beneficiary Association Workers Compensation
# Project Fund 2017 Bond
# Project Fund 2018 Bond
# 2019 Pay-As-You-Go
# Project Fund 2019 Bond
# 2018 Pay-As-You-Go
# Pennsylvania Emergency Management Agency and Homeland Security
# Green Initiative Trust Fund
# Capital Project Fund
# Schenley Park Rink Trust Fund
# Liquid Fuels Tax
# 2016 Pay-As-You-Go
# Project Fund 2020 Bond
# Transportation Improvement Program Projects
# Fire Escrow
# Project Fund 2012 Bond
# Real Estate Tax Refunds City
# 2017 Pay-As-You-Go
# Real Estate Tax Refunds School
# Employee Travel Expense Advance Trust Fund
# Demolition Trust Fund
# Hazardous Materials Trust Fund
# 2014 Pay-As-You-Go
# Crossing Guard Special Events
# Pittsburgh Code Trust Fund
# Public Safety Training Trust Fund
# 2015 Pay-As-You-Go
# Confiscated Non-Narcotics Proceeds
# Code Trust Fund
# Microfilm Permit Plans Trust Fund
# Pittsburgh Commission on Human Relations Trust Fund
# Verizon Franchise Trust Fund
# Capital Projects 2006 Bond
# Mounted Police Trust Fund
# Graffiti Trust Fund
# South Side Parking Enhancement
# Comcast Franchise Trust Fund
# Frick Park Trust Fund
# Public Safety Support Trust Fund
# Escheat Fund
# District 9 Crime Prevention
# Housing Opportunities for Persons With AIDS
# 2013 Pay-As-You-Go
# Federal Task Force Trust Fund
# York County Planning Commission Mayor's Youth Initiative Trust Fund
# Appalachian Regional Commission
# Workforce Development Fund
# Stormwater Management Trust Fund
# Drug Abuse Resistance Education Trust Fund
# Brownfield Economic Development Fund
# Other Post-Employment Benefits Trust Fund Police
# Operation Weed and Seed Fund
# Facilities Trust Fund
# Wayfinders Signage Trust Fund
# Criminal Intelligence Fund
# State Emergency Shelter Program
# Other Post-Employment Benefits Trust Fund Fire
# Phipps Conservatory Fund
# Auto Theft Task Force II Trust Fund
# Pittsburgh Area National Geospatial-Intelligence Agency Trust Fund
# Vending Trust Fund Controller
# Ethics Board Trust Fund
# Earned Income Tax Refunds City
# Local Law Enforcement Fund
# Highway Safety Trust Fund
# Rental Permit Trust Fund
# Open Space Trust Fund
# Earned Income Tax Refunds School
# Stimulus Fund
# Other Post-Employment Benefits Trust Fund
# Liberty Avenue Bike Lane Grant
# Homelessness Prevention and Rapid Re-Housing Program
# Swimming Pool Maintenance Trust Fund
# Copier Management and Postage Trust Fund
# Controller's Financial Management Information System

# %% [markdown]
# ## Extracting out necessary information only

# %%
# Getting only the necessary columns for fund_df
fund_df = df[['fund_id', 'fund_description', 'fund_description_key']].drop_duplicates()
department_df = df[['department_id', 'department_name', 'department_name_key']].drop_duplicates()
cost_center_df = df[['cost_center_id', 'cost_center_description', 'cost_center_description_key']].drop_duplicates()
ledger_df = df[['id', 'general_ledger_date', 'amount', 'ledger_description', 'fund_id', 'department_id','cost_center_id']]

# %% [markdown]
# ## Final check if dataset is clean

# %%
# Check if ledger_df.id is unique
is_ledger_id_unique = ledger_df['id'].nunique() == len(ledger_df)
print(f"Are all ledger_df.id values unique? {is_ledger_id_unique}")
print(f"Ledger df shape? {ledger_df.shape}")

# Check if fund_df.fund_id is unique
is_fund_id_unique = fund_df['fund_id'].nunique() == len(fund_df)
print(f"Are all fund_df.fund_id values unique? {is_fund_id_unique}")

# Check if department_df.department_id is unique
is_department_id_unique = department_df['department_id'].nunique() == len(department_df)
print(f"Are all department_df.department_id values unique? {is_department_id_unique}")


# Check if cost_center_df.cost_center_id is unique
is_cost_center_id_unique = cost_center_df['cost_center_id'].nunique() == len(cost_center_df)
print(f"Are all cost_center_df.cost_center_id values unique? {is_cost_center_id_unique}")
# Out:
# Are all ledger_df.id values unique? True
# Ledger df shape? (609499, 7)
# Are all fund_df.fund_id values unique? True
# Are all department_df.department_id values unique? True
# Are all cost_center_df.cost_center_id values unique? True

# %% [markdown]
# ## If dataset has duplicate values in the id column, find those entries

# %%
# Identify non-unique fund_ids in fund_df
non_unique_fund_ids = fund_df[fund_df['fund_id'].duplicated(keep=False)]

# Display the non-unique rows
print(non_unique_fund_ids)

# Identify non-unique department_ids in department_df
non_unique_department_ids = department_df[department_df['department_id'].duplicated(keep=False)]

# Display the non-unique rows
print(non_unique_department_ids)

# Identify non-unique department_ids in department_df
non_unique_cost_center_ids = cost_center_df[cost_center_df['cost_center_id'].duplicated(keep=False)]

# Display the non-unique rows
print(non_unique_cost_center_ids)
# Out:
# Empty DataFrame
# Columns: [fund_id, fund_description, fund_description_key]
# Index: []
# Empty DataFrame
# Columns: [department_id, department_name, department_name_key]
# Index: []
# Empty DataFrame
# Columns: [cost_center_id, cost_center_description, cost_center_description_key]
# Index: []

# %% [markdown]
# ## Save the dataset to their respective path in the current directory

# %%
ledger_df.to_csv('dataset/ledger.csv', index=False)
fund_df.to_csv('dataset/fund.csv', index=False)
department_df.to_csv('dataset/department.csv', index=False)
cost_center_df.to_csv('dataset/cost_center.csv', index=False)

# %%
import pandas as pd

# Load your CSV files
department_df = pd.read_csv('dataset/department.csv')
fund_df = pd.read_csv('dataset/fund.csv')
ledger_df = pd.read_csv('dataset/ledger.csv')
cost_center_df = pd.read_csv('dataset/cost_center.csv')

# Function to convert DataFrame to SQL INSERT statements and split into files
def df_to_sql_insert_split(df, table_name, max_rows_per_file=1000000):
    insert_statements = []
    file_count = 1
    for index, row in df.iterrows():
        columns = ', '.join(row.index)
        values = ', '.join([f"'{str(value)}'" if isinstance(value, str) else str(value) for value in row.values])
        insert_statements.append(f"INSERT INTO {table_name} ({columns}) VALUES ({values});")
        
        # If we have reached the max rows per file, write to a new file
        if (index + 1) % max_rows_per_file == 0 or index == len(df) - 1:
            filename = f'insert_{table_name}_sql_statements_part_{file_count}.sql'
            with open(filename, 'w') as file:
                file.write('USE revex_insights;\n' + '\n'.join(insert_statements))
            insert_statements = []  # Reset for the next file
            file_count += 1

# Convert DataFrames to SQL INSERT statements and split into files
df_to_sql_insert_split(department_df, 'department')
df_to_sql_insert_split(fund_df, 'fund')
df_to_sql_insert_split(ledger_df, 'ledger')
df_to_sql_insert_split(cost_center_df, 'cost_center')

# %%
import pandas as pd

# Load your CSV files
department_df = pd.read_csv('dataset/department.csv')
fund_df = pd.read_csv('dataset/fund.csv')
ledger_df = pd.read_csv('dataset/ledger.csv')
cost_center_df = pd.read_csv('dataset/cost_center.csv')

# Function to convert DataFrame to SQL INSERT statements and split into files
def df_to_sql_insert_split(df, table_name, max_rows_per_file=1000000):
    insert_statements = []
    file_count = 1
    
    for index, row in df.iterrows():
        columns = ', '.join(row.index)  # Column names
        
        values = []
        for value in row.values:
            if isinstance(value, str):
                escaped_value = value.replace("'", "''")  # Escape single quotes
                values.append(f"'{escaped_value}'")
            else:
                values.append(str(value))  # Keep numbers as they are
        
        values_str = ', '.join(values)
        insert_statements.append(f"INSERT INTO {table_name} ({columns}) VALUES ({values_str});")
        
        # If we have reached max rows per file, write to a new file
        if (index + 1) % max_rows_per_file == 0 or index == len(df) - 1:
            filename = f'insert_{table_name}_sql_statements_part_{file_count}.sql'
            with open(filename, 'w') as file:
                file.write('USE revex_insights;\n' + '\n'.join(insert_statements) + '\n')
            insert_statements = []  # Reset for the next file
            file_count += 1

# Convert DataFrames to SQL INSERT statements and split into files
df_to_sql_insert_split(department_df, 'department')
df_to_sql_insert_split(fund_df, 'fund')
df_to_sql_insert_split(ledger_df, 'ledger')
df_to_sql_insert_split(cost_center_df, 'cost_center')
